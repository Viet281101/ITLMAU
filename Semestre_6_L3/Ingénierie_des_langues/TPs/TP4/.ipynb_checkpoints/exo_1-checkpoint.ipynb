# %% [markdown]
# # TP4 : Génération de texte avec des chaînes de Markov¶

# %% [markdown]
# ## Exercice 1 : chaîne de Markov de premier ordre (unigrammes)

# %%
import numpy as np

# %%
def doc_to_word_list(path):
	'''
	paramètre : chemin vers un corpus
	returns : liste de liste 
		- liste de phrases
		- chaque phrase est une liste de tokens
	'''
	with open(path) as input_stream:
		lines = input_stream.readlines()
		lines = [line.strip() for line in lines]
		lines = [line.split() for line in lines]
	return lines

# %% [markdown]
# ### Compter les transitions

# %%
def count_unigram_transitions(corpus):
	'''
	paramètre : corpus (séquence de séquence de tokens)
	returns : dictionnaire à deux niveaux contenant pour chaque mot le nombre d'apparitions pour chaque mot suivant possible.
	'''
	transitions = {}
	
	for sentence in corpus:
		for i in range(len(sentence)-1):
			if sentence[i] not in transitions:
				transitions[sentence[i]] = {}
			if sentence[i+1] not in transitions[sentence[i]]:
				transitions[sentence[i]][sentence[i+1]] = 0
			transitions[sentence[i]][sentence[i+1]] += 1

	return transitions

# %%
corpus = []
corpus.extend(doc_to_word_list("proust/2998-0.txt"))
print(count_unigram_transitions(corpus))
# Out:
# {'\ufeffMa': {'mère,': 1}, 'mère,': {'quand': 2, 'peut-être': 1, 'pleine': 1, 'si': 1, 'je': 1, 'de': 1, "j'aime": 1, 'assure': 1, 'elle': 1, 'et,': 1, 'pour': 1, 'elle,': 1, 'soit': 1, 'ce': 1}, 'quand': {'il': 36, 'ils': 7, 'on': 13, 'je': 21, 'elle': 9, "c'est": 1, 'un': 4, 'ma': 1, 'cette': 1, 'le': 2, 'à': 3, 'la': 4, 'nous': 9, 'Sa': 1, 'Swann': 3, "j'épouserai": 1, "l'être": 1, 'cet': 1, 'par': 1, 'elles': 3, 'tout': 2, 'mon': 2, "j'étais": 1, 'Mme': 3, 'Odette': 1, "l'Altesse": 1, "n'aimant": 1, 'plus': 1, "j'eus": 2, 'Benozzo': 1, 'Gilberte': 4, "l'auditeur": 1, 'Bergotte,': 1, "j'ai": 1, 'Bergotte': 1, "l'occasion": 1, "l'avis": 1, 'même': 1, "j'aurais": 1, 'viendrait': 1, 'du': 4, 'leur': 1, 'dans': 1, 'ces': 1}, 'il': {'fut': 4, 'était': 18, "s'était": 5, "s'y": 1, 'ne': 28, 'se': 14, 'redevenait': 1, 'fallait': 4, 'débitait': 1, 'le': 8, 'avait': 29, 'y': 41, "n'a": 3, "s'ouvre": 1, 'pouvait': 2, 'apercevait': 1, 'jetait': 1, 'venait': 1, 'croyait': 1, 'est': 23, "t'y": 1, 'réglera': 1, 'a': 13, 'me': 21, 'faut': 11, 'dit': 2, 'représentait': 1, 'savait': 1, 'exerçait': 1, 'cherchait': 1, 'prit': 1, "s'est": 1, "n'est": 8, 'sembla': 1, 'pourra': 1, 'estimait': 2, 'trouvait': 2, 'justifierait': 1, "n'avait": 4, 'les': 4, 'trouve': 1, 'régalait': 1, "l'a": 1, 'appartient': 1, 'aurait': 4, 'suffisait': 3, "n'hésita": 1, 'éveille,': 1, "n'appose": 1, 'faudra': 1, 'semble': 2, "n'y": 10, 'allât': 1, 'publiait': 1, 'épousa': 1, "l'amènerait,": 1, 'inventait,': 1, "l'avait": 1, 'attachait': 1, 'fait': 2, "m'annonça": 1, "n'en": 2, 'insinuait': 1, 'va': 1, 'en': 4, 'devienne': 1, 'allait': 2, "n'eût": 1, 'habitait': 1, 'semblait': 4, 'voyait': 4, 'répondit': 2, 'nous': 3, 'vit,': 1, "s'agit": 4, 'arriva': 1, 'la': 3, "m'arriva,": 1, 'faudrait': 1, 'parlait': 1, "s'agissait": 2, "l'y": 1, 'mettait': 2, 'faisait': 3, 'fût': 1, 'constate': 1, 'cherchât': 2, 'devait': 1, 'achetait': 1, 'préférait': 1, "n'était": 6, 'cessait': 1, 'souffrait': 1, "n'aurait": 1, 'vous': 3, 'ajoutait': 1, "s'ajoute": 1, 'cessa': 1, 'monta': 1, 'détestait': 1, 'voulait': 1, "n'eut": 1, 'pût': 1, "s'en": 1, 'peut': 1, 'hérite': 1, "m'intimidait": 1, 'devait,': 1, 'prenait': 1, 'sera': 1, "n'allait": 1, 'valait': 1, 'eût': 1, 'délaie': 1, 'pleuvait;': 1, 'arrive': 1, 'concentra': 1, 'revenait': 1, 'lui': 1, "n'apprécierait": 1}, 'fut': {'question': 1, 'si': 1, 'celui': 2, 'sans': 2, 'changé,': 1, 'une': 3, 'interrompu': 1, 'suivie': 1, 'levé': 1, 'écarté,': 1, 'seulement': 1, 'arrivée': 1, 'provoqué': 1, 'dite.': 1, 'grand,': 1, 'pas': 4, 'grande': 1, 'pour': 1, 'justement': 2, 'présenté': 1, 'peut-être': 1, 'parti,': 1, 'par': 1, 'un': 1, 'loin:': 1, 'révélé,': 1, 'pris': 1, 'ensuite': 1, 'à': 1, 'vers': 1, 'lui': 1, 'ouverte,': 1, 'comme': 1, 'attendu': 1}, 'question': {"d'avoir": 1, "d'un": 1, 'au': 1, 'que': 1, "d'intérêt": 1, 'sur': 1}, "d'avoir": {'pour': 2, 'enfin': 1, 'du': 1, 'un': 2, "l'air": 2, 'été': 2, 'appris': 1, 'une': 1, 'connus': 1, 'à': 1, 'dîné': 1, 'la': 1, "l'automobile": 1, 'trouvé': 1, 'rendu': 1, 'de': 1}, 'pour': {'la': 39, 'ce': 3, 'mesurer': 1, 'nous': 7, 'lesquels': 1, 'rien,': 2, 'Swann,': 1, 'Cottard': 1, 'finir': 2, 'ne': 14, 'qui': 5, 'rapprocher': 1, 'très': 1, 'décider': 2, 'vide,': 1, 'cette': 2, 'pouvoir': 4, 'lui,': 6, 'leur': 2, 'M.': 1, 'me': 7, 'un': 15, 'moi': 23, "qu'il": 6, 'elle': 4, 'longtemps': 1, 'que': 15, 'jamais,': 2, 'but': 1, 'le': 26, 'les': 14, 'toutes.': 1, 'abréger': 1, 'ma': 3, 'moi,': 7, 'lequel': 2, 'elle,': 5, 'faire': 9, 'ses': 6, 'tout': 3, 'réciter': 1, 'se': 6, "l'exil,": 1, 'cela': 6, 'son': 7, 'parler': 1, 'elles': 1, 'mon': 5, "qu'au": 2, 'tâcher': 2, 'savoir': 2, "l'Angleterre": 1, 'contribuer': 1, 'lui': 11, 'peu': 2, 'être': 6, 'sa': 3, 'resserrer': 1, 'lui.': 2, 'une': 14, 'juger': 1, 'eux-mêmes': 1, 'vous': 5, 'en': 1, "l'Art,": 1, 'Bergotte,': 2, 'quelques': 1, 'résultat': 1, 'Mme': 2, 'elles,': 1, 'rendre': 2, 'aller': 8, 'quelque': 3, 'telles': 1, 'Françoise': 1, 'repartir': ...

# %% [markdown]
# ### Des effectifs aux probabilités

# %%
def probabilify(comptes_transitions):
	'''
	paramètre : dictionnaire de transitions
	returns : dictionnaire à deux niveaux contenant pour chaque mot la probabilité d'apparition pour chaque mot suivant possible. 
	'''
	probabilites = {}
	for word in comptes_transitions:
		probabilites[word] = {}
		total = sum(comptes_transitions[word].values())
		for next_word in comptes_transitions[word]:
			probabilites[word][next_word] = comptes_transitions[word][next_word] / total
	return probabilites

# %%
print(probabilify(count_unigram_transitions(corpus)) )
# Out:
# {'\ufeffMa': {'mère,': 1.0}, 'mère,': {'quand': 0.13333333333333333, 'peut-être': 0.06666666666666667, 'pleine': 0.06666666666666667, 'si': 0.06666666666666667, 'je': 0.06666666666666667, 'de': 0.06666666666666667, "j'aime": 0.06666666666666667, 'assure': 0.06666666666666667, 'elle': 0.06666666666666667, 'et,': 0.06666666666666667, 'pour': 0.06666666666666667, 'elle,': 0.06666666666666667, 'soit': 0.06666666666666667, 'ce': 0.06666666666666667}, 'quand': {'il': 0.22929936305732485, 'ils': 0.044585987261146494, 'on': 0.08280254777070063, 'je': 0.1337579617834395, 'elle': 0.05732484076433121, "c'est": 0.006369426751592357, 'un': 0.025477707006369428, 'ma': 0.006369426751592357, 'cette': 0.006369426751592357, 'le': 0.012738853503184714, 'à': 0.01910828025477707, 'la': 0.025477707006369428, 'nous': 0.05732484076433121, 'Sa': 0.006369426751592357, 'Swann': 0.01910828025477707, "j'épouserai": 0.006369426751592357, "l'être": 0.006369426751592357, 'cet': 0.006369426751592357, 'par': 0.006369426751592357, 'elles': 0.01910828025477707, 'tout': 0.012738853503184714, 'mon': 0.012738853503184714, "j'étais": 0.006369426751592357, 'Mme': 0.01910828025477707, 'Odette': 0.006369426751592357, "l'Altesse": 0.006369426751592357, "n'aimant": 0.006369426751592357, 'plus': 0.006369426751592357, "j'eus": 0.012738853503184714, 'Benozzo': 0.006369426751592357, 'Gilberte': 0.025477707006369428, "l'auditeur": 0.006369426751592357, 'Bergotte,': 0.006369426751592357, "j'ai": 0.006369426751592357, 'Bergotte': 0.006369426751592357, "l'occasion": 0.006369426751592357, "l'avis": 0.006369426751592357, 'même': 0.006369426751592357, "j'aurais": 0.006369426751592357, 'viendrait': 0.006369426751592357, 'du': 0.025477707006369428, 'leur': 0.006369426751592357, 'dans': 0.006369426751592357, 'ces': 0.006369426751592357}, 'il': {'fut': 0.01020408163265306, 'était': 0.04591836734693878, "s'était": 0.012755102040816327, "s'y": 0.002551020408163265, 'ne': 0.07142857142857142, 'se': 0.03571428571428571, 'redevenait': 0.002551020408163265, 'fallait': 0.01020408163265306, 'débitait': 0.002551020408163265, 'le': 0.02040816326530612, 'avait': 0.07397959183673469, 'y': 0.10459183673469388, "n'a": 0.007653061224489796, "s'ouvre": 0.002551020408163265, 'pouvait': 0.00510204081632653, 'apercevait': 0.002551020408163265, 'jetait': 0.002551020408163265, 'venait': 0.002551020408163265, 'croyait': 0.002551020408163265, 'est': 0.058673469387755105, "t'y": 0.002551020408163265, 'réglera': 0.002551020408163265, 'a': 0.03316326530612245, 'me': 0.05357142857142857, 'faut': 0.02806122448979592, 'dit': 0.00510204081632653, 'représentait': 0.002551020408163265, 'savait': 0.002551020408163265, 'exerçait': 0.002551020408163265, 'cherchait': 0.002551020408163265, 'prit': 0.002551020408163265, "s'est": 0.002551020408163265, "n'est": 0.02040816326530612, 'sembla': 0.002551020408163265, 'pourra': 0.002551020408163265, 'estimait': 0.00510204081632653, 'trouvait': 0.00510204081632653, 'justifierait': 0.002551020408163265, "n'avait": 0.01020408163265306, 'les': 0.01020408163265306, 'trouve': 0.002551020408163265, 'régalait': 0.002551020408163265, "l'a": 0.002551020408163265, 'appartient': 0.002551020408163265, 'aurait': 0.01020408163265306, 'suffisait': 0.007653061224489796, "n'hésita": 0.002551020408163265, 'éveille,': 0.002551020408163265, "n'appose": 0.002551020408163265, 'faudra': 0.002551020408163265, 'semble': 0.00510204081632653, "n'y": 0.025510204081632654, 'allât': 0.002551020408163265, 'publiait': 0.002551020408163265, 'épousa': 0.002551020408163265, "l'amènerait,": 0.002551020408163265, 'inventait,': 0.002551020408163265, "l'avait": 0.002551020408163265, 'attachait': 0.002551020408163265, 'fait': 0.00510204081632653, "m'annonça": 0.002551020408163265, "n'en": 0.00510204081632653, 'insinuait': 0.002551020408163265, 'va': 0.002551020408163265, 'en': 0.01020408163265306, 'devienne': 0.002551020408163265, 'allait': 0.00510204081632653, "n'eût": 0.002551020408163265, 'habitait': 0.00255102040816 ...

# %% [markdown]
# ### Créer une chaîne de Markov d'ordre 1

# %%
def markov_chain_unigram(corpus):
	transitions = count_unigram_transitions(corpus)
	return probabilify(transitions)

# %%
markov_chain = markov_chain_unigram(corpus)

# %%
print(markov_chain["le"])
# Out:
# {'regret': 0.001081081081081081, 'Professeur': 0.001081081081081081, 'marquis': 0.002162162162162162, 'désir,': 0.002162162162162162, 'rang': 0.001081081081081081, 'plaisir': 0.004324324324324324, 'snobisme': 0.001081081081081081, 'plus': 0.03567567567567568, 'reverra,': 0.001081081081081081, 'changement': 0.002162162162162162, 'père': 0.0075675675675675675, 'fard': 0.002162162162162162, 'phénomène': 0.001081081081081081, 'don': 0.004324324324324324, 'seul': 0.006486486486486486, 'prendre.': 0.001081081081081081, 'monde,': 0.008648648648648649, 'passé': 0.003243243243243243, 'rendre': 0.002162162162162162, '_Journal': 0.001081081081081081, 'peut': 0.001081081081081081, 'mépris': 0.002162162162162162, 'moins': 0.005405405405405406, 'retour': 0.001081081081081081, 'premier.': 0.001081081081081081, 'monde': 0.018378378378378378, 'gala': 0.001081081081081081, 'souverain': 0.001081081081081081, 'genre': 0.006486486486486486, 'domaine,': 0.001081081081081081, 'conduisant': 0.001081081081081081, 'service': 0.002162162162162162, 'louer': 0.001081081081081081, 'même': 0.02918918918918919, 'régime': 0.002162162162162162, 'nom': 0.014054054054054054, 'ramènerai': 0.001081081081081081, 'directeur': 0.002162162162162162, 'jour': 0.014054054054054054, 'prestige': 0.002162162162162162, 'départ': 0.001081081081081081, 'titre': 0.004324324324324324, 'particulier': 0.001081081081081081, 'programme': 0.001081081081081081, 'temps': 0.011891891891891892, 'sous-entendu': 0.001081081081081081, 'rideau': 0.003243243243243243, 'théâtre,': 0.002162162162162162, 'reste': 0.002162162162162162, 'monument': 0.001081081081081081, 'four': 0.001081081081081081, 'vocabulaire': 0.002162162162162162, 'mot': 0.006486486486486486, 'petit': 0.0075675675675675675, 'théâtre': 0.001081081081081081, 'sort,': 0.001081081081081081, 'pouvoir': 0.005405405405405406, 'milieu': 0.003243243243243243, 'symbole': 0.002162162162162162, 'centre': 0.002162162162162162, 'poussin': 0.001081081081081081, 'public': 0.004324324324324324, 'compte': 0.002162162162162162, 'récompensât': 0.001081081081081081, 'génie': 0.002162162162162162, 'fond,': 0.001081081081081081, 'soin': 0.002162162162162162, 'rôle': 0.003243243243243243, 'son': 0.004324324324324324, 'talent': 0.001081081081081081, 'décor': 0.001081081081081081, 'tableau': 0.001081081081081081, 'verre': 0.002162162162162162, 'moment': 0.008648648648648649, 'surprend': 0.001081081081081081, 'peuple': 0.001081081081081081, 'coup': 0.001081081081081081, 'vent': 0.004324324324324324, 'vin': 0.001081081081081081, 'besoin': 0.004324324324324324, 'prolonger,': 0.001081081081081081, 'dîner': 0.003243243243243243, 'meilleur': 0.002162162162162162, 'désir.': 0.001081081081081081, 'conseil': 0.002162162162162162, 'caractère': 0.005405405405405406, 'marteau': 0.001081081081081081, 'fils': 0.004324324324324324, 'quai': 0.001081081081081081, 'fusil': 0.001081081081081081, 'succès': 0.002162162162162162, 'voir': 0.003243243243243243, 'lendemain': 0.0075675675675675675, '4%': 0.001081081081081081, 'revenu': 0.001081081081081081, 'capital.»': 0.001081081081081081, 'reste,': 0.002162162162162162, 'sourire': 0.002162162162162162, 'dernier': 0.003243243243243243, 'rendit.': 0.001081081081081081, 'faisait': 0.003243243243243243, 'ton': 0.005405405405405406, 'piano,': 0.001081081081081081, 'diplomate': 0.001081081081081081, 'prier': 0.001081081081081081, 'provoquer': 0.001081081081081081, 'goût': 0.008648648648648649, 'choix': 0.002162162162162162, 'jeu': 0.001081081081081081, 'bœuf': 0.002162162162162162, 'parfum': 0.004324324324324324, 'trouver': 0.001081081081081081, 'critérium': 0.001081081081081081, 'mets': 0.001081081081081081, 'roi': 0.0075675675675675675, 'veux': 0.002162162162162162, 'nôtre': 0.002162162162162162, 'rapprochement': 0.001081081081081081, 'Ministre': 0.001081081081081081, 'connais': 0.002162162162162162, 'connaîtrait?': 0.001081081081081081, 'cœur': 0.004324324324324324, 'sien.': 0.001081081081081081, 'candidat': 0.0010810810810810 ...

# %% [markdown]
# ### Générer des phrases avec votre chaîne de Markov

# %%
ponctuation = [".", "!", "?", "…", ":", ";", ",", "(", ")", "[", "]", "{", "}", "«", "»", "“", "”", "‘", "’", "—", "–", "-", " ", "\n", "\t", "\r "]
NB_MOTS_MAXI = 100

def generate_unigram(markov_chain, start_token):
	'''
	paramètre : chaîne de Markov, token de départ
	returns : liste de tokens
	'''
	phrase = [start_token]
	for i in range(NB_MOTS_MAXI):
		if phrase[-1] not in markov_chain:
			break
		proba = markov_chain[phrase[-1]]
		next_word = np.random.choice(list(proba.keys()), p=list(proba.values()))
		if next_word in ponctuation:
			phrase.append(next_word)
			break
		phrase.append(next_word)
	return phrase

# %%
print(generate_unigram(markov_chain, "Si"))
# Out:
# ['Si', "j'avais", 'été', 'donné', 'la', 'botanique', "qu'à", 'Mme', 'Swann,', 'mais', 'dans', 'le', 'plus', 'de', 'Mme', 'Swann', 'savait-il', 'pas', "m'être", 'vanté', 'comme', 'un', 'tour', "l'une", "d'elles,", 'de', 'pied', 'sur', 'nos', 'vertus', 'de', 'faire', 'ce', 'genre', "d'hommes", 'qui', 'nous', 'avons', 'lu', 'le', 'holà,', "l'homme", 'des', 'hommes', 'politiques,', 'fussent-ils', 'francs-maçons,', 'qui', "s'en", 'allant', 'tandis', "qu'elle", 'sembla', 'que', "s'il", 'avait', 'continué', 'à', 'Madame', 'Swann', 'avait', 'été,', 'vit', 'dans', 'lequel', "j'étais", 'persuadé', 'que', "l'aspect", 'sommaire', 'de', 'vérité,', 'mais', 'au', 'moins', "d'une", 'personne', 'qui', 'pût', 'y', 'avait', 'eu', 'un', 'peu', 'usitée', "qu'elle", 'pût', 'voir', 'Gilberte,', 'dans', 'le', 'coffre', 'de', 'dire', 'elle', 'a', 'rendu.', 'Il', 'faut', 'lui', 'avais']

# %% [markdown]
# ### Améliorer la génération
