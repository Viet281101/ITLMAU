# %% [markdown]
# # TP4 : Génération de texte avec des chaînes de Markov

# %% [markdown]
# ## Exercice 2 : chaîne de Markov d'ordre 2 (bigrammes)

# %%
import numpy as np

# %%
def doc_to_word_list(path):
	'''
	paramètre : chemin vers un corpus
	returns : liste de liste 
		- liste de phrases
		- chaque phrase est une liste de tokens
	'''
	with open(path) as input_stream:
		lines = input_stream.readlines()
		lines = [line.strip() for line in lines]
		lines = [line.split() for line in lines]
	return lines

# %%
def count_unigram_transitions(corpus):
	'''
	paramètre : corpus (séquence de séquence de tokens)
	returns : dictionnaire à deux niveaux contenant pour chaque mot le nombre d'apparitions pour chaque mot suivant possible.
	'''
	transitions = {}
	
	for sentence in corpus:
		for i in range(len(sentence)-1):
			if sentence[i] not in transitions:
				transitions[sentence[i]] = {}
			if sentence[i+1] not in transitions[sentence[i]]:
				transitions[sentence[i]][sentence[i+1]] = 0
			transitions[sentence[i]][sentence[i+1]] += 1

	return transitions

# %%
def probabilify(comptes_transitions):
	'''
	paramètre : dictionnaire de transitions
	returns : dictionnaire à deux niveaux contenant pour chaque mot la probabilité d'apparition pour chaque mot suivant possible. 
	'''
	probabilites = {}
	for word in comptes_transitions:
		probabilites[word] = {}
		total = sum(comptes_transitions[word].values())
		for next_word in comptes_transitions[word]:
			probabilites[word][next_word] = comptes_transitions[word][next_word] / total
	return probabilites

# %%
def compter_transitions_bigrammes(corpus):
	transitions = {}
	
	for sentence in corpus:
		for i in range(len(sentence)-1):
			if sentence[i] not in transitions:
				transitions[sentence[i]] = {}
			if sentence[i+1] not in transitions[sentence[i]]:
				transitions[sentence[i]][sentence[i+1]] = 0
			transitions[sentence[i]][sentence[i+1]] += 1
	
	return transitions

# %%
corpus = []
corpus.extend(doc_to_word_list("proust/2998-0.txt"))
compter_transitions_bigrammes(corpus)
# Out:
# {'\ufeffMa': {'mère,': 1},
#  'mère,': {'quand': 2,
#   'peut-être': 1,
#   'pleine': 1,
#   'si': 1,
#   'je': 1,
#   'de': 1,
#   "j'aime": 1,
#   'assure': 1,
#   'elle': 1,
#   'et,': 1,
#   'pour': 1,
#   'elle,': 1,
#   'soit': 1,
#   'ce': 1},
#  'quand': {'il': 36,
#   'ils': 7,
#   'on': 13,
#   'je': 21,
#   'elle': 9,
#   "c'est": 1,
#   'un': 4,
#   'ma': 1,
#   'cette': 1,
#   'le': 2,
#   'à': 3,
#   'la': 4,
#   'nous': 9,
#   'Sa': 1,
#   'Swann': 3,
#   "j'épouserai": 1,
#   "l'être": 1,
#   'cet': 1,
#   'par': 1,
#   'elles': 3,
#   'tout': 2,
#   'mon': 2,
#   "j'étais": 1,
#   'Mme': 3,
#   'Odette': 1,
#   "l'Altesse": 1,
#   "n'aimant": 1,
#   'plus': 1,
#   "j'eus": 2,
#   'Benozzo': 1,
#   'Gilberte': 4,
#   "l'auditeur": 1,
#   'Bergotte,': 1,
#   "j'ai": 1,
#   'Bergotte': 1,
#   "l'occasion": 1,
#   "l'avis": 1,
#   'même': 1,
#   "j'aurais": 1,
#   'viendrait': 1,
#   'du': 4,
#   'leur': 1,
#   'dans': 1,
#   'ces': 1},
#  'il': {'fut': 4,
#   'était': 18,
#   "s'était": 5,
#   "s'y": 1,
#   'ne': 28,
#   'se': 14,
#   'redevenait': 1,
#   'fallait': 4,
#   'débitait': 1,
#   'le': 8,
#   'avait': 29,
#   'y': 41,
#   "n'a": 3,
#   "s'ouvre": 1,
#   'pouvait': 2,
#   'apercevait': 1,
#   'jetait': 1,
#   'venait': 1,
#   'croyait': 1,
#   'est': 23,
#   "t'y": 1,
#   'réglera': 1,
#   'a': 13,
#   'me': 21,
#   'faut': 11,
#   'dit': 2,
#   'représentait': 1,
#   'savait': 1,
#   'exerçait': 1,
#   'cherchait': 1,
#   'prit': 1,
#   "s'est": 1,
#   "n'est": 8,
#   'sembla': 1,
#   'pourra': 1,
#   'estimait': 2,
#   'trouvait': 2,
#   'justifierait': 1,
#   "n'avait": 4,
#   'les': 4,
#   'trouve': 1,
#   'régalait': 1,
#   "l'a": 1,
#   'appartient': 1,
#   'aurait': 4,
#   'suffisait': 3,
#   "n'hésita": 1,
#   'éveille,': 1,
#   "n'appose": 1,
#   'faudra': 1,
#   'semble': 2,
#   "n'y": 10,
#   'allât': 1,
#   'publiait': 1,
#   'épousa': 1,
#   "l'amènerait,": 1,
#   'inventait,': 1,
#   "l'avait": 1,
#   'attachait': 1,
#   'fait': 2,
#   "m'annonça": 1,
#   "n'en": 2,
#   'insinuait': 1,
#   'va': 1,
#   'en': 4,
#   'devienne': 1,
#   'allait': 2,
#   "n'eût": 1,
#   'habitait': 1,
#   'semblait': 4,
#   'voyait': 4,
#   'répondit': 2,
#   'nous': 3,
#   'vit,': 1,
#   "s'agit": 4,
#   'arriva': 1,
#   'la': 3,
#   "m'arriva,": 1,
#   'faudrait': 1,
#   'parlait': 1,
#   "s'agissait": 2,
#   "l'y": 1,
#   'mettait': 2,
#   'faisait': 3,
#   'fût': 1,
#   'constate': 1,
#   'cherchât': 2,
#   'devait': 1,
#   'achetait': 1,
#   'préférait': 1,
#   "n'était": 6,
#   'cessait': 1,
#   'souffrait': 1,
#   "n'aurait": 1,
#   'vous': 3,
#   'ajoutait': 1,
#   "s'ajoute": 1,
#   'cessa': 1,
#   'monta': 1,
#   'détestait': 1,
#   'voulait': 1,
#   "n'eut": 1,
#   'pût': 1,
#   "s'en": 1,
#   'peut': 1,
#   'hérite': 1,
#   "m'intimidait": 1,
#   'devait,': 1,
#   'prenait': 1,
#   'sera': 1,
#   "n'allait": 1,
#   'valait': 1,
#   'eût': 1,
#   'délaie': 1,
#   'pleuvait;': 1,
#   'arrive': 1,
#   'concentra': 1,
#   'revenait': 1,
#   'lui': 1,
#   "n'apprécierait": 1},
#  'fut': {'question': 1,
#   'si': 1,
#   'celui': 2,
#   'sans': 2,
#   'changé,': 1,
#   'une': 3,
#   'interrompu': 1,
#   'suivie': 1,
#   'levé': 1,
#   'écarté,': 1,
#   'seulement': 1,
#   'arrivée': 1,
#   'provoqué': 1,
#   'dite.': 1,
#   'grand,': 1,
#   'pas': 4,
#   'grande': 1,
#   'pour': 1,
#   'justement': 2,
#   'présenté': 1,
#   'peut-être': 1,
#   'parti,': 1,
#   'par': 1,
#   'un': 1,
#   'loin:': 1,
#   'révélé,': 1,
#   'pris': 1,
#   'ensuite': 1,
#   'à': 1,
#   'vers': 1,
#   'lui': 1,
#   'ouverte,': 1,
#   'comme': 1,
#   'attendu': 1},
#  'question': {"d'avoir": 1,
#   "d'un": 1,
#   'au': 1,
#   'que': 1,
#   "d'intérêt": 1,
#   'sur': 1},
#  "d'avoir": {'pour': 2,
#   'enfin': 1,
#   'du': 1,
#   'un': 2,
#   "l'air": 2,
#   'été': 2,
#   'appris': 1,
#   'une': 1,
#   'connus': 1,
#   'à': 1,
#   'dîné': 1,
#   'la': 1,
#   "l'automobile": 1,
#   'trouvé': 1,
#   'rendu': 1,
#   'de': 1},
#  'pour': {'la': 39,
#   'ce': 3,
#   'mesurer': 1,
#   'nous': 7,
#   'lesquels': 1,
#   'rien,': 2,
#   'Swann,': 1,
#   'Cottard': 1,
#   'finir': 2,
#   'ne': 14,
#   'qui': 5,
#   'rapprocher': 1,
#   'très': 1,
#   'décider': 2,
#   'vide,': 1,
#   'cette': 2,
#   'pouvoir': 4,
#   'lui,': 6,
#   'leur': 2,
#   'M.': 1,
#   'me': 7,
#   'un': 15,
#   'moi': 23,
#   "qu'il": 6,
#   'elle': 4,
#   'longtemps': 1,
#   'que': 15,
#   'jamais,': 2,
#   'but': 1,
#   'le': 26,
#   'les': 14,
#   'toutes.': 1,
#   'abréger': 1,
#   'ma': 3,
#   'moi,': 7,
#   'lequel': 2,
#   'elle,': 5,
#   'faire': 9,
#   'ses': 6,
#   'tout': 3,
#   'réciter': 1,
#   'se': 6,
#   "l'exil,": 1,
#   'cela': 6,
#   'son': 7,
#   'parler': 1,
#   'elles': 1,
#   'mon': 5,
#   "qu'au": 2,
#   'tâcher': 2,
#   'savoir': 2,
#   "l'Angleterre": 1,
#   'contribuer': 1,
#   'lui': 11,
#   'peu': 2,
#   'être': 6,
#   'sa': 3,
#   'resserrer': 1,
#   'lui.': 2,
#   'une': 14,
#   'juger': 1,
#   'eux-mêmes': 1,
#   'vous': 5,
#   'en': 1,
#   "l'Art,": 1,
#   'Bergotte,': 2,
#   'quelques': 1,
#   'résultat': 1,
#   'Mme': 2,
#   'elles,': 1,
#   'rendre': 2,
#   'aller': 8,
#   'quelque': 3,
#   'telles': 1,
#   'Françoise': 1,
#   'repartir': 1,
#   "qu'elle": 3,
#   'y': 3,
#   'bien': 1,
#   "l'avenir,": 2,
#   'calmer': 1,
#   'regarder': 1,
#   'moi:': 1,
#   'lui--seraient': 1,
#   'retourner': 1,
#   'avoir': 4,
#   "m'aider": 1,
#   'garder': 2,
#   'faire,': 1,
#   'tous': 4,
#   'médecin,': 1,
#   'voir': 3,
#   'toujours': 2,
#   'nombreuse': 1,
#   'descendre»,': 1,
#   'procéder': 1,
#   'effacer': 1,
#   'moi.': 3,
#   'camarade,': 1,
#   'rien': 1,
#   "l'époque,": 1,
#   'eux': 1,
#   'eux.': 1,
#   "l'esprit": 2,
#   'des': 4,
#   'certaines': 1,
#   'remplir': 1,
#   'nous.': 2,
#   'ceux': 2,
#   'réaliser': 1,
#   'de': 1,
#   'tirer': 1,
#   'Odette': 1,
#   'réveiller': 1,
#   'venger': 1,
#   'midi': 1,
#   "qu'on": 1,
#   'offrir': 1,
#   "s'épargner": 1,
#   'éviter': 1,
#   'simplifier,': 1,
#   "l'avenir": 1,
#   'plus': 1,
#   'écarter': 1,
#   'cela,': 1,
#   'nul': 1,
#   'notre': 2,
#   "l'auteur": 1,
#   "s'amuser,": 1,
#   'donner': 2,
#   'sortir': 1,
#   "qu'elles": 1,
#   'sept': 1,
#   'assister': 1,
#   'cela.': 1,
#   'soi,': 1,
#   'élégants': 1,
#   'Bergotte': 1,
#   "l'un": 1,
#   'toutes': 2,
#   'celui': 1,
#   'condition': 1,
#   'signifier': 2,
#   'toujours.': 1,
#   'eux-mêmes,': 1,
#   'laquelle': 3,
#   'arriver': 2,
#   'veiller': 1,
#   "l'empêcher": 1,
#   'sortir,': 1,
#   'plusieurs': 1,
#   'prendre': 1,
#   "s'excuser": 1,
#   'mes': 1,
#   'corollaire': 1,
#   'vous,': 1,
#   'gens': 1,
#   '«sortir».': 1,
#   'deux': 1,
#   'toi.': 1,
#   'commencer': 1,
#   'subordonner': 1,
#   "m'obliger": 1,
#   'désirer': 1,
#   'objet': 1,
#   'revenir': 1,
#   'celui-ci--à': 1,
#   'soi-même': 1,
#   'celle': 1,
#   "s'excuser.": 1,
#   'toujours,': 1,
#   'ainsi': 1,
#   'toujours;': 1,
#   '_moi_,': 1,
#   'elle.': 1,
#   'eux--quand': 1,
#   'dire:': 1,
#   'ennuyer': 1,
#   'rentrer.': 1,
#   "l'eczéma": 1,
#   'trouver': 1},
#  'la': {'première': 21,
#   'plus': 24,
#   'modestie': 1,
#   'discrétion.': 1,
#   'dernière),': 1,
#   'compagne': 1,
#   'connaître)': 1,
#   'femme': 19,
#   'simplicité': 1,
#   'vanité': 2,
#   'principale': 2,
#   'disponibilité': 1,
#   'mise': 1,
#   'fin': 9,
#   'critique': 2,
#   'Patronne,': 1,
#   'Raspelière.': 1,
#   'parole': 3,
#   'longue,': 1,
#   'Faculté,': 1,
#   'promptitude,': 1,
#   'sûreté': 1,
#   'nature': 4,
#   'seconde': 3,
#   'guerre': 4,
#   'France': 1,
#   'Dette,': 1,
#   'leur': 1,
#   'France,': 5,
#   'naissance': 1,
#   'République': 1,
#   'valeur),': 1,
#   'stérile': 1,
#   'branche': 1,
#   'diplomatie,': 4,
#   'carrière,': 1,
#   'crainte': 2,
#   'différence': 2,
#   'communauté': 1,
#   'consanguinité': 1,
#   'Commission,': 1,
#   'sensibilité': 1,
#   'rondeur': 1,
#   'gaieté': 1,
#   'Commission': 2,
#   'puissance': 2,
#   'Prusse,': 1,
#   'conversation': 13,
#   'même': 22,
#   'charmait': 1,
#   'bonne': 1,
#   'vie': 25,
#   'cuisine': 2,
#   'poste,': 1,
#   'concernaient': 1,
#   'diplomatie': 2,
#   'maison,': 9,
#   'Berma,': 13,
#   'réussite': 1,
#   'carrière': 2,
#   'littérature,': 3,
#   'Commission.': 2,
#   '_Revue': 2,
#   'plume': 1,
#   'chance': 2,
#   'prochaine': 2,
#   'Berma': 32,
#   'grande': 7,
#   'valeur': 7,
#   'simple': 1,
#   'réalisation': 3,
#   'voix': 8,
#   'noblesse,': 1,
#   'douleur,': 1,
#   'colonne': 4,
#   'semaine': 2,
#   'noblesse': 1,
#   'forme': 4,
#   'visite': 3,
#   'tirade:': 1,
#   'dérobait': 1,
#   'plaquette': 1,
#   'divine': 1,
#   'Déesse': 1,
#   'séance': 1,
#   'défense': 1,
#   'peine': 5,
#   'vérité,': 3,
#   'tendresse,': 2,
#   'perfection': 1,
#   'Berma.': 6,
#   'perfection,': 1,
#   'Sage': 1,
#   'joie': 5,
#   'distribution': 2,
#   'lisais': 1,
#   'représentation': 3,
#   'veille,': 1,
#   'gelée,': 1,
#   'qualité': 4,
#   'fabrication': 1,
#   'veille': 3,
#   'fois': 5,
#   'meilleure': 4,
#   'brûlante': 1,
#   'cruelle': 1,
#   'tête': 5,
#   'claque': 1,
#   'moindre': 2,
#   'poussière': 2,
#   'température': 1,
#   'salle,': 2,
#   'tenue': 1,
#   'salle': 9,
#   'proximité': 1,
#   'coquille': 1,
#   'planète': 1,
#   'scène': 5,
#   'pièce,': 1,
#   'scène,': 1,
#   'petite': 9,
#   'vertu,': 1,
#   'profondeur': 2,
#   'figure': 5,
#   'distribution,': 1,
#   'réplique': 1,
#   'première.': 2,
#   'relation': 1,
#   'signification': 3,
#   'peur': 4,
#   'gênât': 1,
#   'mesure': 1,
#   'durée': 1,
#   'hauteur': 4,
#   'mer,': 1,
#   'réalité': 8,
#   'lorgnette;': 1,
#   'vraie?': 1,
#   'déclaration': 1,
#   'tirade': 1,
#   'débita': 1,
#   'monotonie': 1,
#   'foule': 3,
#   'frontière': 1,
#   'véritable': 1,
#   'perception': 1,
#   'victoire,': 1,
#   'force': 7,
#   'mer': 4,
#   'supériorité': 3,
#   'Joconde,': 1,
#   'mienne,': 3,
#   'main,': 3,
#   'soirée': 2,
#   'satisfaction': 2,
#   'sorte': 5,
#   'fois,': 2,
#   'majestueuse': 1,
#   'curiosité': 3,
#   'Littérature': 1,
#   'maîtrise': 1,
#   'conversation,': 5,
#   'cause': 2,
#   'voie': 2,
#   'fortune': 3,
#   '«composition»': 1,
#   'suivre': 1,
#   'Cote,': 1,
#   'devanture': 1,
#   'Compagnie': 1,
#   'tendresse': 4,
#   'parfaite': 1,
#   'Commission...»': 1,
#   'phrase': 5,
#   'faisait': 1,
#   'netteté': 1,
#   'découvrir;': 1,
#   'vérité': 4,
#   'tête,': 2,
#   'laisser': 2,
#   'vulgarité': 3,
#   'sert': 1,
#   'réalité;': 1,
#   'vie,': 6,
#   'gelée': 3,
#   'colle,': 1,
#   'littérature.': 3,
#   'pareille,': 1,
#   'sottise,': 1,
#   'salade': 1,
#   'pénétration': 1,
#   'mangea': 1,
#   'cour': 2,
#   'race': 1,
#   'surprise.': 1,
#   'loi': 1,
#   'Consulta,': 1,
#   'galerie': 1,
#   'danse': 1,
#   'caravane': 1,
#   'culture': 2,
#   '_Revue_,': 1,
#   'politique': 2,
#   'monarchie': 1,
#   'manière': 5,
#   'route': 1,
#   'grosse': 1,
#   'pittoresque': 1,
#   'presse': 1,
#   'matière': 3,
#   'tristesse': 4,
#   'perle': 1,
#   'Sainte-Chapelle': 1,
#   'pierre': 1,
#   'dentelle.': 1,
#   'belle': 4,
#   'douceur': 3,
#   'discrétion': 1,
#   'malice.': 1,
#   'société': 7,
#   'part': 6,
#   'Nesselrode!': 1,
#   'cure': 1,
#   'femme,': 1,
#   'mode': 1,
#   'femme;': 1,
#   'réalité.': 1,
#   'connaissait': 1,
#   'répétait': 1,
#   'maxime': 1,
#   'vie:': 1,
#   'conduite': 1,
#   'plupart': 2,
#   'racine': 1,
#   'perspective': 2,
#   'foi': 1,
#   'duchesse': 13,
#   'princesse': 11,
#   'mort': 6,
#   'présentation': 1,
#   'motive,': 1,
#   'présenter': 2,
#   'réunion': 1,
#   'modération': 1,
#   'pénétration.': 1,
#   'base': 1,
#   'complexité': 2,
#   'carte': 1,
#   'Sacro-Sainte': 1,
#   'conscience,': 2,
#   'mauvaise': 2,
#   'charrue': 1,
#   'mienne': 1,
#   'médiocrité': 3,
#   'triste': 1,
#   'réponse,': 1,
#   'charge,': 1,
#   'fille': 2,
#   'voir': 7,
#   'situation': 6,
#   'fluidité': 1,
#   'philosophie': 1,
#   'conservation': 1,
#   'courte': 1,
#   'façon': 6,
#   'composition': 1,
#   'liste': 1,
#   'ligne': 4,
#   'circonstance--ne': 1,
#   'certitude': 2,
#   'ferait': 1,
#   'connaissait,': 1,
#   'maîtresse': 4,
#   'maison': 10,
#   'mission': 1,
#   'volupté,': 1,
#   'gloire': 2,
#   'beauté': 6,
#   '«carrière».': 1,
#   'liberté': 1,
#   'peine.': 1,
#   'terre': 1,
#   'vie.': 3,
#   'suivante': 1,
#   'campagne.': 1,
#   'cordialité': 1,
#   'taquinerie': 1,
#   'cuisine.': 3,
#   'fière': 2,
#   'hiérarchie': 1,
#   'croisée': 1,
#   'cuisine,': 1,
#   'va-vite,': 1,
#   'crème.--Est-ce': 1,
#   'place': 3,
#   'rue': 7,
#   'table,': 1,
#   'jeunesse.»': 1,
#   'parenté.': 1,
#   'nôtre,': 2,
#   'remît': 1,
#   'lettre': 8,
#   'détruirait,': 1,
#   'lèvre': 1,
#   'merci': 1,
#   '«carte-album»,': 1,
#   'sensation': 3,
#   'connaissance': 4,
#   'Création,': 1,
#   'même,': 1,
#   'maison.': 5,
#   'rue,': 2,
#   'troupe': 1,
#   'pensée': 7,
#   'nuit': 3,
#   'Mi-Carême,': 1,
#   'confusion': 1,
#   'Porte-Saint-Martin': 1,
#   'Porte': 1,
#   'voir,': 6,
#   'personne': 3,
#   'marchande': 1,
#   'musique,': 1,
#   'poussant': 1,
#   'voir.': 1,
#   'priant': 1,
#   'lui': 3,
#   'pureté': 1,
#   'bonté': 2,
#   'générosité': 1,
#   'sympathie': 2,
#   'suite': 3,
#   'généralité': 1,
#   'tenancière': 2,
#   'croyait': 1,
#   'lie': 1,
#   'famille': 3,
#   'marquise,': 1,
#   'jugeait': 1,
#   'sincérité': 1,
#   'mit': 1,
#   'faire': 2,
#   'tenais': 1,
#   'gymnastique': 1,
#   'suie,': 1,
#   'neige': 2,
#   'circulation': 1,
#   'glace': 1,
#   'nourriture': 1,
#   '«sévérité»,': 1,
#   '«virulence»': 1,
#   'poussée': 1,
#   'désapprobation': 1,
#   'caféine': 1,
#   'bière,': 1,
#   'vue': 1,
#   'rassurasse.': 1,
#   'soirée,': 1,
#   'respiration': 2,
#   'porte': 4,
#   'bronchite': 1,
#   'mode,': 2,
#   'toux': 1,
#   'suite,': 2,
#   'patrie': 1,
#   'seule': 8,
#   'barre': 1,
#   'savais': 1,
#   'vraie,': 2,
#   'lettre,': 1,
#   'nouvelle': 2,
#   'peinture,': 1,
#   'relire,': 1,
#   'respiration,': 1,
#   'terre,': 1,
#   'souffrance': 1,
#   'ruse': 1,
#   'soudaineté': 1,
#   'douleur.': 1,
#   'dernière': 2,
#   'verrait,': 1,
#   'finesse': 1,
#   'photographie,': 1,
#   'sombre': 1,
#   'possibilité': 1,
#   'main': 4,
#   'liaison': 1,
#   'feuille,': 1,
#   'signature': 1,
#   'série': 1,
#   'devise:': 1,
#   'cérémonie': 1,
#   'dignité': 1,
#   'provenance': 1,
#   '_Vie': 1,
#   'zone': 1,
#   'majesté': 1,
#   'destruction': 1,
#   'pâtisserie': 1,
#   'notion': 1,
#   'famille,': 1,
#   'prévision': 1,
#   'table:': 1,
#   'permission': 2,
#   'fâcheuse': 1,
#   'bienveillance': 2,
#   'Bibliothèque': 1,
#   'théorie': 1,
#   'demeure': 3,
#   'multitude': 1,
#   'voix,': 1,
#   '«patronne»,': 1,
#   'conversation».': 1,
#   'porte,': 1,
#   'tête.': 1,
#   'boutique,': 1,
#   'Légion': 1,
#   'fameuse': 1,
#   'connais': 2,
#   'voyais': 1,
#   'guerre,': 1,
#   'visite,': 1,
#   'publicité.': 1,
#   'déclarer': 1,
#   'naïveté': 1,
#   'recevait,': 1,
#   'trouver': 1,
#   'recevait.': 1,
#   'Raison': 1,
#   'duchesse.': 1,
#   'duchesse,': 2,
#   'personne.': 1,
#   'nouvelle,': 1,
#   'présence': 2,
#   'stupéfaction': 1,
#   'dame': 5,
#   'période': 2,
#   'corruption,': 1,
#   'nôtre.': 1,
#   'haute': 1,
#   'côtoient': 1,
#   'comtesse': 1,
#   'cocotte': 2,
#   'lecture': 3,
#   'soif': 1,
#   'paresse': 1,
#   'perfectionner)': 1,
#   'continuation': 1,
#   'crise).': 1,
#   'faveur': 2,
#   'partie': 2,
#   'moins': 2,
#   'princesse.': 1,
#   'poudre': 1,
#   'lune,': 1,
#   'catégorie': 1,
#   'honte': 1,
#   'bouche': 1,
#   'jalousie,': 1,
#   'personnalité': 1,
#   'douloureuse': 1,
#   'jalousie)': 1,
#   'route,': 1,
#   'craindrait': 1,
#   'jalousie': 3,
#   '«femme': 1,
#   'jeune': 1,
#   'pelouse': 1,
#   'suppression': 1,
#   'faim),': 1,
#   'lumière': 2,
#   'crème,': 1,
#   'chaleur': 1,
#   'tempête,': 1,
#   'reine,': 1,
#   'matinée': 1,
#   'célébration': 1,
#   'messe': 1,
#   'voyant': 2,
#   'pièce': 2,
#   'lingerie,': 1,
#   'montrer': 1,
#   'forcerait': 1,
#   'donnait': 1,
#   'deuxième,': 1,
#   'troisième': 1,
#   'dixième.': 1,
#   'compréhension,': 1,
#   'mémoire.': 1,
#   'mémoire': 2,
#   'minute': 1,
#   'récite': 1,
#   'Sonate': 5,
#   'photographie': 1,
#   'sonate': 1,
#   'distance': 1,
#   'brume': 2,
#   'mélancolie': 1,
#   'possédai': 1,
#   'dernière.': 1,
#   'quitterons': 1,
#   'postérité': 3,
#   'postérité,': 2,
#   'peinture': 2,
#   'musique': 4,
#   'dissonance,': 1,
#   'non': 1,
#   'fausseté': 2,
#   'raison': 2,
#   'fraîcheur.': 1,
#   'Sonate,': 2,
#   '«Volonté': 1,
#   '«Synthèse': 1,
#   'cour.': 1,
#   'Nativité,': 1,
#   'Tamise': 1,
#   'mère': 2,
#   'connaîtrai,': 1,
#   'haie': 2,
#   'forme,': 1,
#   'connaissais': 2,
#   'fois.': 1,
#   'volonté': 1,
#   'croyance': 1,
#   'singularité,': 1,
#   'merveilleuse': 1,
#   'dame,': 1,
#   'releva': 1,
#   'nièce': 1,
#   'Princesse': 1,
#   'surprise': 1,
#   'correspondance': 1,
#   'portât': 1,
#   'plante': 1,
#   'conversation.': 1,
#   'révérence': 1,
#   'transparence': 1,
#   'chose': 2,
#   'prit': 1,
#   'demande': 1,
#   'mis': 1,
#   'transparente': 1,
#   'solution': 2,
#   'barbiche': 1,
#   'ressemblance': 1,
#   'gêne': 1,
#   'redingote': 1,
#   'vie)': 1,
#   'tige': 1,
#   'boutonnière': 1,
#   'messe,': 1,
#   'pensée:': 1,
#   'sonorité': 1,
#   'Bergotte».': 1,
#   'découverte': 1,
#   'rigueur': 2,
#   'variété': 1,
#   'variété,': 1,
#   'diction': 1,
#   'prendre': 1,
#   'chevelure': 3,
#   'fatigue': 1,
#   'faculté': 1,
#   'causerie,': 1,
#   'précédente': 1,
#   'ville,': 1,
#   'nature,': 2,
#   'première:': 1,
#   'paresse,': 1,
#   'retouche': 1,
#   'déférence': 2,
#   'tendance': 1,
#   'comédie.': 1,
#   'règle': 1,
#   'société,': 1,
#   'thèse': 1,
#   'méchanceté': 1,
#   'douleur': 1,
#   'verticalité': 1,
#   'boucle': 1,
#   'revoir': 1,
#   'sœur': 1,
#   'représentation.': 1,
#   'plénitude': 1,
#   'réalité,': 1,
#   'brochure,': 1,
#   'vengeance': 1,
#   'complète,': 1,
#   'rectifie;': 1,
#   'sentence': 1,
#   'digestion,': 1,
#   'provision': 1,
#   'chemise': 1,
#   '«vie»),': 1,
#   'sujétion': 1,
#   'rend': 1,
#   'peau': 3,
#   'joue': 1,
#   'journée': 2,
#   'présentera': 1,
#   'disputaient,': 1,
#   'proie': 1,
#   'retrouver': 2,
#   'concevrait': 1,
#   'campagne,': 1,
#   'sincérité,': 1,
#   'confiance,': 1,
#   'joie,': 1,
#   'conquête': 1,
#   'difficulté': 1,
#   'stupidité': 1,
#   'sienne,': 1,
#   'lagune.': 1,
#   'réponse': 2,
#   'queue': 1,
#   'loge': 1,
#   'fresque': 1,
#   'confirmation': 1,
#   'louange': 1,
#   'toxine': 1,
#   'vertu': 1,
#   'dépravation': 1,
#   'possession': 1,
#   'beauté,': 1,
#   'longévité': 1,
#   'réalité:': 1,
#   'séduction': 1,
#   'patronne': 4,
#   'proposait': 1,
#   'patronne:': 1,
#   'comprendre': 1,
#   'tisane': 1,
#   'tenait': 1,
#   'chambre': 1,
#   'quitter': 1,
#   'résistance': 3,
#   'fièvre.': 1,
#   'vision': 2,
#   'rappela': 1,
#   'devinant': 1,
#   'recrudescence': 1,
#   'pluie,': 1,
#   'pendule,': 1,
#   'banalité': 1,
#   'pendule': 1,
#   'fin,': 1,
#   'réjouir,': 1,
#   'laissant,': 1,
#   'croire,': 1,
#   'retrouver.': 1,
#   'fierté': 1,
#   'faiblesse': 1,
#   'funeste': 1,
#   'bouée': 1,
#   'science': 1,
#   'gare,': 1,
#   'résolution)': 1,
#   'radiographie': 1,
#   'terrible': 1,
#   'reverrais': 1,
#   'sienne.': 1,
#   'supposition': 1,
#   'perdre': 1,
#   'voir)': 1,
#   'nuit,': 1,
#   'profusion': 1,
#   'botanique': 1,
#   'lampe': 1,
#   'patience': 1,
#   'nudité': 1,
#   'fenêtre': 1,
#   'boutonnière,': 1,
#   'conduire': 1,
#   'tasse': 1,
#   'couleur': 1,
#   'rencontrer': 1,
#   'du': 1,
#   'trouvait': 1,
#   'femme--dans': 1,
#   'plupart,': 1,
#   'soie': 1,
#   'splendeur': 1,
#   'main.': 1,
#   'réserve': 1,
#   'démission': 1,
#   'séparation.': 1,
#   'position': 1,
#   'Guerre': 1,
#   'Patronne': 5,
#   'fleur': 1,
#   'Réaction!»': 1,
#   'Patronne.': 1,
#   'suivre.': 1,
#   'ramener': 1,
#   'reconduire.': 1,
#   'Loi': 1,
#   'porte.--Chère': 1},
#  'première': {'fois': 9,
#   'fois--en': 1,
#   'fois,': 4,
#   'matinée': 1,
#   'bouchée': 1,
#   'minute': 1,
#   'communion,': 1,
#   'fois.': 2,
#   'fois».': 1,
#   'audition,': 1,
#   'visite': 1,
#   'ligne': 1,
#   'faute,': 1,
#   'est': 1,
#   'neige,': 1},
#  'fois': {'M.': 1,
#   'faite': 1,
#   'la': 2,
#   'pour': 1,
#   '(et': 1,
#   "qu'elle": 4,
#   'York': 1,
#   "qu'on": 1,
#   'levé--quand': 1,
#   'en': 2,
#   'que': 13,
#   'des': 1,
#   'à': 5,
#   'plus': 2,
#   'de': 5,
#   'sur': 1,
#   'non!': 1,
#   "qu'il": 5,
#   "l'Ambassadeur": 1,
#   'par': 4,
#   'son': 1,
#   'un': 2,
#   'une': 1,
#   'conquis': 1,
#   'mes': 1,
#   'naturel': 1,
#   'rentré': 1,
#   'il': 2,
#   'timbré': 1,
#   'toutes': 1,
#   "qu'Odette": 1,
#   "quelqu'un": 1,
#   'cette': 1,
#   "d'un": 1,
#   'sa': 1,
#   'contenté': 1,
#   "d'aller": 1,
#   'le': 1,
#   'dans': 2,
#   'je': 3,
#   'entre': 1,
#   'les': 1,
#   'où': 2,
#   "d'autant": 1,
#   'devant': 1,
#   'autant.': 1,
#   'dix.': 1},
#  'M.': {'de': 96,
#   'Georges': 1,
#   'Anatole': 1,
#   'votre': 1,
#   'De': 1,
#   'Poirier_.': 1,
#   'Swann': 3,
#   'et': 8,
#   'ou': 1,
#   'Verdurin': 1,
#   'Le': 1,
#   'Swann.': 3,
#   'Moreul.': 1,
#   'Swann,': 1},
#  'Norpois': {'à': 2,
#   'eût': 2,
#   'passait': 1,
#   "m'a": 1,
#   'avait': 4,
#   'est': 2,
#   'était': 2,
#   'un': 2,
#   'étaient': 1,
#   'sur': 2,
#   'de': 2,
#   'fit': 1,
#   'je': 1,
#   'lui': 1,
#   "n'est": 1,
#   "m'offrait": 1,
#   "m'en": 1,
#   'porta': 1,
#   'eut': 1,
#   'après': 1,
#   'en': 3,
#   'pour': 1,
#   'se': 1,
#   "s'arrêta": 1,
#   'excellait': 1,
#   'écrivit': 1,
#   'leva': 1,
#   'avec': 2,
#   '(qui': 1,
#   'venait': 1,
#   "n'en": 1,
#   "l'avait": 1,
#   'parut': 1,
#   'était,': 1,
#   'savait': 1,
#   'parlait': 1,
#   'et': 3,
#   'qui': 1,
#   'fût': 1,
#   'fut': 1,
#   'a': 1,
#   "n'eut": 1,
#   'apprenant': 1,
#   'ne': 2,
#   'ôtait': 1},
#  'à': {'dîner,': 2,
#   'la': 156,
#   'fréquenter': 1,
#   'qui': 15,
#   'les': 3,
#   'Madame': 3,
#   'ce': 41,
#   'tour': 4,
#   "l'humanité": 1,
#   'se': 16,
#   'leurs': 6,
#   'son': 22,
#   'Combray,': 6,
#   'un': 38,
#   'même': 1,
#   'ses': 8,
#   'servir,': 1,
#   'M.': 9,
#   'craindre': 1,
#   'considérer': 2,
#   '«percer»': 1,
#   'tous': 9,
#   'tout': 13,
#   "l'éloge": 1,
#   'leur': 14,
#   'côté': 15,
#   'dîner;': 1,
#   'ma': 12,
#   'une': 31,
#   'fait': 15,
#   'aussi': 1,
#   'en': 7,
#   'rendre': 2,
#   'mon': 20,
#   'admirer': 1,
#   'peine': 11,
#   "l'interlocuteur,": 1,
#   'répondre': 1,
#   'tant': 3,
#   'nous': 9,
#   'y': 2,
#   "n'importe": 1,
#   'garder,': 1,
#   'risquer': 1,
#   'entendre': 2,
#   "l'intérêt": 1,
#   "l'idée": 2,
#   'ne': 7,
#   'Paris.': 1,
#   'laisser': 1,
#   'eux': 1,
#   'fresque,': 1,
#   'Mme': 25,
#   'table,': 5,
#   'mes': 5,
#   'Balbec,': 2,
#   'Venise': 1,
#   '_Phèdre_.': 1,
#   'chaque': 4,
#   "l'esprit:": 1,
#   'cette': 16,
#   "m'occuper": 1,
#   'moi-même': 3,
#   'travers': 6,
#   '_Phèdre_': 1,
#   'peu': 11,
#   "l'attrait": 1,
#   'vrai': 4,
#   "l'un": 1,
#   "l'orchestre": 2,
#   'deux': 4,
#   'sa': 18,
#   'cet': 7,
#   'composer,': 1,
#   'choisir': 3,
#   'longue': 1,
#   'traverser.': 1,
#   'distinguer': 1,
#   'coup,': 3,
#   'notre': 8,
#   'écrire': 2,
#   'étudier': 1,
#   'force': 1,
#   "l'intensité": 1,
#   'descendre': 1,
#   'moi.': 2,
#   'Hippolyte,': 1,
#   'des': 15,
#   'cent': 1,
#   'faux,': 1,
#   'grossir,': 1,
#   'mesure': 2,
#   '_Phèdre_,': 1,
#   'Paris': 2,
#   'Pétersbourg,': 1,
#   'Munich': 1,
#   'Sofia,': 1,
#   'quelle': 3,
#   'faire.': 2,
#   "l'étranger,": 1,
#   'observer': 1,
#   'montrer': 1,
#   'Rome': 1,
#   'Dresde,': 1,
#   'Combray': 5,
#   'elle.': 2,
#   'coup': 3,
#   'répétition': 1,
#   'bord': 1,
#   'faible': 1,
#   'féliciter': 1,
#   'ces': 14,
#   'connaître,': 2,
#   "l'émission": 1,
#   'confondre': 1,
#   "l'Ambassadeur.": 1,
#   'certaines': 2,
#   'ceux': 4,
#   'être': 6,
#   'laquelle': 11,
#   'faire': 11,
#   'bien': 1,
#   'me': 15,
#   'obtenir': 1,
#   'remplacer': 2,
#   'déclarer': 2,
#   'ravir,': 1,
#   'lui': 15,
#   "l'étranger": 3,
#   "l'agrément": 1,
#   'celui': 6,
#   "l'ordre": 1,
#   "l'Elysée,": 1,
#   'merveille,': 1,
#   'commencer': 1,
#   'Vaugoubert,': 1,
#   'Rome,': 3,
#   'gages': 1,
#   'demander': 2,
#   'émailler': 1,
#   'point': 1,
#   'sentir': 1,
#   "l'Académie": 2,
#   'écrire:': 1,
#   'Londres': 2,
#   'merveille': 2,
#   'demi': 2,
#   'maîtriser': 1,
#   "l'emporte-pièce.": 1,
#   "l'emploi": 1,
#   'certaine': 1,
#   'vaincre.': 1,
#   'voir': 4,
#   'quoi': 2,
#   'fait,': 1,
#   'savoir': 2,
#   'fond': 2,
#   'eux,': 4,
#   "l'habitude": 1,
#   "l'intelligence": 1,
#   'lui,': 3,
#   'elle': 4,
#   'mettre': 1,
#   "l'intéressé": 1,
#   'cause': 17,
#   'accoupler': 1,
#   'Odette,': 2,
#   'Gilberte,': 4,
#   'lui-même': 1,
#   'si': 1,
#   'parler': 5,
#   'Monseigneur': 1,
#   'de': 1,
#   'vous,': 1,
#   'condition': 1,
#   "l'autre": 3,
#   'votre': 5,
#   "l'heure": 6,
#   "l'homme": 1,
#   "d'autres": 2,
#   'jour': 1,
#   'Bergotte': 7,
#   'moi,': 5,
#   'Vienne,': 1,
#   'quinze': 1,
#   'Gilberte': 9,
#   "l'avenir": 1,
#   'avoir': 2,
#   'chacun': 1,
#   'autrui;': 1,
#   'plus': 5,
#   'aucune': 1,
#   "l'oubli": 1,
#   'vous': 2,
#   'moi': 4,
#   'trouver': 1,
#   "l'efficacité,": 1,
#   "l'entendre": 3,
#   'celle': 7,
#   'expier': 1,
#   'employer': 1,
#   'maman:': 1,
#   'déprécier.': 1,
#   'reproduire': 1,
#   'Françoise,': 1,
#   'apprendre,': 1,
#   "quelqu'un": 1,
#   "l'apercevoir": 1,
#   'dates': 1,
#   'droite': 1,
#   "m'avertir": 1,
#   'temps': 1,
#   "l'amant,": 1,
#   "l'amour,": 2,
#   'aller': 4,
#   'toutes': 5,
#   'désirer,': 1,
#   'faire,': 1,
#   "l'égard": 7,
#   "l'écart": 2,
#   'abstraire': 1,
#   'le': 4,
#   'attendre': 1,
#   'interroger': 1,
#   'joues': 1,
#   'perruque': 1,
#   'cache-cache.': 1,
#   'Combray.': 2,
#   'penser': 4,
#   "m'y": 2,
#   'aucune.': 1,
#   'mener': 1,
#   'manger': 3,
#   'peine,': 2,
#   'respirer,': 1,
#   'plaindre,': 1,
#   'sortir.': 1,
#   'bas.': 1,
#   'prendre': 1,
#   "l'hôpital": 1,
#   'cacher': 1,
#   'redire': 1,
#   'elle,': 1,
#   'vivre,': 1,
#   'plonger,': 1,
#   'lutter': 1,
#   'deviner,': 1,
#   "l'entretenir.": 1,
#   'reconnaître': 1,
#   "l'aide": 3,
#   'chercher': 1,
#   'jamais': 1,
#   'lettres': 2,
#   'retirer': 1,
#   'petits': 1,
#   'dessins,': 2,
#   'manger,': 2,
#   'Swann': 3,
#   'opérer': 1,
#   'résoudre': 2,
#   'quel': 1,
#   "l'insuffisance": 1,
#   "l'impossibilité": 2,
#   'saint': 1,
#   'distance': 2,
#   'tenir': 1,
#   'supprimer': 1,
#   'raconter.': 1,
#   'sept': 1,
#   'idées': 1,
#   'revoir': 1,
#   "l'écart»?": 1,
#   'rien,': 3,
#   'discerner,': 1,
#   'aimer': 3,
#   'différents': 1,
#   'attirer': 2,
#   'pénétrer': 1,
#   'chevaux.': 1,
#   "l'étonnement": 1,
#   "l'aéroplane.": 1,
#   'Odette': 3,
#   "l'époque": 1,
#   'quelques-unes': 1,
#   "l'aristocratie": 1,
#   'chacune': 1,
#   'Cottard:': 1,
#   'Forcheville.': 1,
#   'Forcheville': 1,
#   'rechercher': 1,
#   'six': 1,
#   'tâcher': 1,
#   "l'extrême": 1,
#   'tort.': 3,
#   'toute': 2,
#   'celle-là': 1,
#   'autre': 3,
#   'entrer': 1,
#   'jeun': 1,
#   'attendre,': 1,
#   'rester': 4,
#   'Swann,': 4,
#   'bannir': 1,
#   "s'y": 1,
#   'moitié': 1,
#   'plusieurs': 3,
#   "l'entendre)": 1,
#   "l'autre,": 1,
#   "m'échapper,": 1,
#   "l'aimer.": 1,
#   'grossir': 1,
#   'venir,': 1,
#   "l'horizon,": 1,
#   'venir': 1,
#   'moi--ce': 1,
#   'Armenonville': 1,
#   'rire:': 1,
#   'Savonarole.': 1,
#   'interpeller': 1,
#   "l'américaine": 1,
#   'connaître': 1,
#   'déjeuner,': 1,
#   'nos': 2,
#   'lacets': 1,
#   'pèlerine': 1,
#   'beaucoup': 1,
#   'tous,': 1,
#   'conséquence': 1,
#   'profiter': 1,
#   'trois': 1,
#   'Son': 1,
#   "l'attente": 1,
#   'dîner.': 1,
#   'table.': 3,
#   'huit': 1,
#   'recommencer.»': 1,
#   "l'écart,": 1,
#   'agir,': 1,
#   'Napoléon': 1,
#   'propos': 1,
#   'part': 2,
#   "l'oreille.": 1,
#   'côté.': 1,
#   'aucun': 1,
#   "l'origine": 1,
#   'déjeuner': 1,
#   'barbiche': 1,
#   'nez': 2,
#   'goutte,': 1,
#   'rien': 3,
#   'réédifier': 1,
#   'quelque': 3,
#   'barbiche.': 1,
#   'genoux': 1,
#   "n'en": 1,
#   'découvert': 1,
#   'découvrir': 1,
#   'contre-sens,': 1,
#   "m'en": 1,
#   'jour;': 1,
#   'soi--et': 1,
#   'suivre': 1,
#   "l'écrivain": 1,
#   'Bergotte,': 2,
#   'nous-même.': 1,
#   "l'état": 1,
#   'partir': 2,
#   'terre': 1,
#   'personne': 1,
#   "l'originalité": 1,
#   "l'estomac": 1,
#   'certains': 3,
#   'soi-même': 1,
#   'supporter,': 1,
#   'supposer': 2,
#   'concevoir': 1,
#   "l'eau,": 1,
#   "l'aubergiste": 1,
#   'barbiche,': 1,
#   "s'adresser": 1,
#   '«repérer»': 1,
#   'distance).': 1,
#   'Œnone': 1,
#   'raconter': 1,
#   'proprement': 1,
#   'répondre.': 1,
#   'recueillir': 1,
#   'Rome.': 1,
#   'Odette.': 1,
#   'Scarron': 1,
#   'demi-déguisée,': 1,
#   'rien.': 1,
#   'nombre': 1,
#   "l'aimer": 1,
#   'Gilberte:': 1,
#   'Œnone:': 1,
#   'celui-ci': 1,
#   'lire': 2,
#   'démêler,': 1,
#   'celles': 1,
#   "l'oreille:": 1,
#   'maman': 2,
#   'Gilberte.': 2,
#   "l'étroit.": 1,
#   'négliger': 1,
#   'croire,': 1,
#   'comprendre': 1,
#   'Swann.': 1,
#   'moi»,': 1,
#   'nouer': 1,
#   "l'adresse": 2,
#   'Bergotte?': 1,
#   'voix': 1,
#   'goûter': 2,
#   'lever.': 1,
#   "l'intérieur": 1,
#   'Bloch--pour': 1,
#   'jamais--une': 1,
#   "l'encre": 1,
#   'gagner.': 1,
#   '«Rachel': 1,
#   'laquelle--malgré': 1,
#   'fabriquer': 1,
#   'former,': 1,
#   'veiller,': 1,
#   "l'aveugle": 1,
#   'travailler,': 1,
#   'dire': 3,
#   "l'accident": 1,
#   'maintenir': 1,
#   'arrêter,': 1,
#   "l'opacité": 1,
#   'échanger,': 1,
#   'détruire': 1,
#   "l'amitié": 1,
#   'fondre': 1,
#   'elle-même:': 1,
#   'lui.': 1,
#   "l'être": 1,
#   'plaire': 1,
#   'vingt': 1,
#   'cinquante.': 1,
#   'qui,': 1,
#   'monsieur': 1,
#   'espérer': 2,
#   'ranimer': 1,
#   'renaître,': 1,
#   'supporter': 1,
#   'attendre.': 1,
#   'traverser': 1,
#   'face': 1,
#   'illuminer': 1,
#   'long': 1,
#   'Mlle': 1,
#   'tel': 1,
#   "l'époque,": 1,
#   "l'existence": 1,
#   'répéter)': 1,
#   'dire.': 1,
#   'accréditer': 1,
#   "l'hiver,": 1,
#   "l'instabilité": 1,
#   'faire»;': 1,
#   "l'imiter.": 1,
#   'lettres.': 1,
#   'moins': 1,
#   "s'excuser": 1,
#   "l'attirer),": 1,
#   'percer,': 1,
#   'rire,': 1,
#   '«grouper»,': 1,
#   'cocarde.': 1,
#   'bientôt,': 1,
#   'donner': 1,
#   "l'aise": 1},
#  'dîner,': {'ayant': 1,
#   'mais': 1,
#   'quand': 1,
#   'demandai-je': 1,
#   'on': 1,
#   'que': 1,
#   'je': 1},
#  'ayant': {'exprimé': 1,
#   'pour': 1,
#   'avant': 1,
#   'changé': 1,
#   'point': 1,
#   'oublié': 1,
#   'persisté': 1,
#   'raconté': 1,
#   'induit': 1,
#   'eu': 1,
#   'à': 2,
#   'pris': 1,
#   'leur': 1,
#   'simplement': 1,
#   'cru': 1,
#   'son': 1,
#   'essuyé': 1,
#   'vécu': 1,
#   'la': 2,
#   'passé': 1,
#   'quelque': 1,
#   'tourné,': 1,
#   'libre': 1,
#   'entendu': 1},
#  'exprimé': {'le': 1, 'par': 1},
#  'le': {'regret': 1,
#   'Professeur': 1,
#   'marquis': 2,
#   'désir,': 2,
#   'rang': 1,
#   'plaisir': 4,
#   'snobisme': 1,
#   'plus': 33,
#   'reverra,': 1,
#   'changement': 2,
#   'père': 7,
#   'fard': 2,
#   'phénomène': 1,
#   'don': 4,
#   'seul': 6,
#   'prendre.': 1,
#   'monde,': 8,
#   'passé': 3,
#   'rendre': 2,
#   '_Journal': 1,
#   'peut': 1,
#   'mépris': 2,
#   'moins': 5,
#   'retour': 1,
#   'premier.': 1,
#   'monde': 17,
#   'gala': 1,
#   'souverain': 1,
#   'genre': 6,
#   'domaine,': 1,
#   'conduisant': 1,
#   'service': 2,
#   'louer': 1,
#   'même': 27,
#   'régime': 2,
#   'nom': 13,
#   'ramènerai': 1,
#   'directeur': 2,
#   'jour': 13,
#   'prestige': 2,
#   'départ': 1,
#   'titre': 4,
#   'particulier': 1,
#   'programme': 1,
#   'temps': 11,
#   'sous-entendu': 1,
#   'rideau': 3,
#   'théâtre,': 2,
#   'reste': 2,
#   'monument': 1,
#   'four': 1,
#   'vocabulaire': 2,
#   'mot': 6,
#   'petit': 7,
#   'théâtre': 1,
#   'sort,': 1,
#   'pouvoir': 5,
#   'milieu': 3,
#   'symbole': 2,
#   'centre': 2,
#   'poussin': 1,
#   'public': 4,
#   'compte': 2,
#   'récompensât': 1,
#   'génie': 2,
#   'fond,': 1,
#   'soin': 2,
#   'rôle': 3,
#   'son': 4,
#   'talent': 1,
#   'décor': 1,
#   'tableau': 1,
#   'verre': 2,
#   'moment': 8,
#   'surprend': 1,
#   'peuple': 1,
#   'coup': 1,
#   'vent': 4,
#   'vin': 1,
#   'besoin': 4,
#   'prolonger,': 1,
#   'dîner': 3,
#   'meilleur': 2,
#   'désir.': 1,
#   'conseil': 2,
#   'caractère': 5,
#   'marteau': 1,
#   'fils': 4,
#   'quai': 1,
#   'fusil': 1,
#   'succès': 2,
#   'voir': 3,
#   'lendemain': 7,
#   '4%': 1,
#   'revenu': 1,
#   'capital.»': 1,
#   'reste,': 2,
#   'sourire': 2,
#   'dernier': 3,
#   'rendit.': 1,
#   'faisait': 3,
#   'ton': 5,
#   'piano,': 1,
#   'diplomate': 1,
#   'prier': 1,
#   'provoquer': 1,
#   'goût': 8,
#   'choix': 2,
#   'jeu': 1,
#   'bœuf': 2,
#   'parfum': 4,
#   'trouver': 1,
#   'critérium': 1,
#   'mets': 1,
#   'roi': 7,
#   'veux': 2,
#   'nôtre': 2,
#   'rapprochement': 1,
#   'Ministre': 1,
#   'connais': 2,
#   'connaîtrait?': 1,
#   'cœur': 4,
#   'sien.': 1,
#   'candidat': 1,
#   'vois': 2,
#   'cadre': 2,
#   'haïr;': 1,
#   'Roi': 1,
#   'péril»': 1,
#   'lecteur': 2,
#   'modèle': 1,
#   'Baron': 1,
#   'masque': 1,
#   'sache': 1,
#   'juste': 1,
#   'comprends.': 1,
#   'dîner,': 2,
#   'répète,': 1,
#   'prime-saut': 1,
#   'récent': 1,
#   'holà,': 1,
#   'saut': 1,
#   'grand': 5,
#   'tombeau': 2,
#   'contrarier': 1,
#   'montre': 1,
#   'gant.': 1,
#   'Directeur': 1,
#   'mariage,': 1,
#   'proclamer': 1,
#   'croit.': 1,
#   'penser,': 1,
#   'trouvait': 1,
#   'lui': 10,
#   'détail': 3,
#   'succès,': 1,
#   'mari': 1,
#   'rendant': 1,
#   'chiffre.': 1,
#   'sût': 1,
#   'moins,': 1,
#   'savait-il': 1,
#   'regard': 3,
#   'Prince': 3,
#   'prince': 7,
#   'comte': 1,
#   'dévouement': 1,
#   'fasse': 1,
#   'sujet': 1,
#   'connaissez?': 1,
#   'connaît': 1,
#   'droit': 1,
#   'rudiment.': 1,
#   '_Cachet': 1,
#   'connaisseur': 1,
#   'mot,': 1,
#   'salon': 7,
#   'geste': 2,
#   'champ': 2,
#   'début': 1,
#   'visage': 3,
#   'dessin': 1,
#   'Monsieur': 1,
#   'décider': 1,
#   'sépare': 1,
#   'transmettre.': 1,
#   'demandait.': 1,
#   'courage,': 1,
#   'nourrir,': 1,
#   'journal': 3,
#   'total': 3,
#   'souvenir': 4,
#   'seuil': 1,
#   'sol': 1,
#   'retrouve': 1,
#   'préau': 1,
#   'passé.': 1,
#   'Temps,': 1,
#   'sais': 1,
#   'fut': 1,
#   'lapin': 2,
#   'mieux': 4,
#   'poulet.': 1,
#   'guet': 1,
#   'voulez)?--Je': 1,
#   'verbe': 1,
#   'mystère': 1,
#   'bœuf,': 1,
#   'jus': 1,
#   'restaurant': 1,
#   'respect': 1,
#   'Café': 1,
#   '1er': 3,
#   'degré': 1,
#   'fût': 1,
#   'faire': 5,
#   'moindre': 1,
#   'relèvement': 1,
#   'couvert': 1,
#   'premier': 4,
#   'crépuscule': 1,
#   'soir.': 1,
#   'savait': 2,
#   'désir': 5,
#   'quartier': 1,
#   'promenait,': 1,
#   'clair': 2,
#   'lendemain,': 3,
#   'problème': 5,
#   'charme': 4,
#   'comptoir': 1,
#   'goût;': 1,
#   'craindre),': 1,
#   'frais,': 1,
#   'dédain': 2,
#   'prononçait,': 1,
#   'moins:': 1,
#   'goûter': 1,
#   'docteur,': 1,
#   'sentais': 1,
#   'secret': 5,
#   'malaise': 1,
#   'soir': 5,
#   'professeur': 3,
#   'mépris,': 1,
#   'train,': 1,
#   'doute': 1,
#   'jugèrent': 1,
#   'firent': 1,
#   'rencontrer.': 1,
#   'dit': 1,
#   'souffle,': 1,
#   'sommeil,': 1,
#   'Jugement': 1,
#   'principal': 1,
#   'bonheur': 3,
#   'Destin': 1,
#   'médecin': 1,
#   'soient': 1,
#   'G': 1,
#   'décidèrent': 1,
#   'gazon': 1,
#   'Vinci!': 1,
#   'Chandelier': 1,
#   'coffre': 1,
#   'crois': 1,
#   'rhume': 1,
#   'dit;': 1,
#   'jouet': 1,
#   'cas': 3,
#   'découronner': 1,
#   'trouble': 1,
#   '«jour»': 1,
#   'fera': 1,
#   'prenez': 1,
#   'thé,': 2,
#   'domaine': 2,
#   'Louvre': 1,
#   'font': 1,
#   'sentiment': 1,
#   'valet': 1,
#   'maniérisme': 1,
#   'pronom': 1,
#   '«petit': 1,
#   'doute,': 1,
#   'ministre!': 1,
#   'ministre,': 1,
#   'gouvernement': 2,
#   'type': 1,
#   'vieux': 1,
#   'baron': 1,
#   'krach': 1,
#   'monde.': 1,
#   'langage': 4,
#   'charme,': 1,
#   'dégoût': 1,
#   'germe': 1,
#   'nombre': 2,
#   'calcul': 1,
#   'surlendemain': 3,
#   'gouverneur': 1,
#   'défaut': 1,
#   '«monde': 1,
#   'tour': 1,
#   '«cousin': 1,
#   'croyant': 1,
#   'malheur': 1,
#   'duc': 2,
#   'père»,': 1,
#   'faubourg': 2,
#   'croyait': 3,
#   'cherchant': 1,
#   'soupçon': 1,
#   'croire': 1,
#   'sens': 1,
#   'leur': 2,
#   'sont,': 1,
#   'robinet': 1,
#   'fait': 1,
#   'feu»,': 1,
#   'trompât': 1,
#   'montrera': 1,
#   'fantôme': 1,
#   'serment,': 1,
#   'long': 2,
#   'déjeuner,': 5,
#   'lunch;': 1,
#   'nœud': 1,
#   'jardinet': 1,
#   'soleil': 3,
#   'spectacle.': 1,
#   'beau': 1,
#   'froid,': 1,
#   'feu': 2,
#   'laboratoire': 1,
#   'flattait': 1,
#   'vide,': 2,
#   'déjeuner.': 1,
#   'bond': 1,
#   'cortège,': 1,
#   'salon,': 2,
#   'mur': 1,
#   'piano': 1,
#   'souvenir.': 1,
#   'collégien': 1,
#   'temps.': 1,
#   'savoir': 2,
#   'fallut': 1,
#   'raccourci': 1,
#   'comprendre,': 2,
#   "chef-d'œuvre": 1,
#   'dangereux': 1,
#   'considère': 1,
#   'facteur': 1,
#   'talent.': 1,
#   'côté': 3,
#   'bois': 1,
#   'contraire;': 1,
#   'Bois': 1,
#   'renseigner,': 1,
#   'motif': 1,
#   'Palmarium': 1,
#   'fond': 2,
#   'Jardin': 2,
#   'prendre': 1,
#   'bon': 2,
#   'portrait': 1,
#   'Cynghalais.--Racontez-le': 1,
#   'mulâtre': 1,
#   'cache»,': 1,
#   'raidillon': 1,
#   'mieux,': 2,
#   'cache': 1,
#   'confronter': 1,
#   'homard': 1,
#   'concernait': 1,
#   'plan': 2,
#   'pouvait': 1,
#   'perçois': 1,
#   'tapis,': 1,
#   'corps': 2,
#   'café,': 1,
#   'tabouret': 1,
#   'reliait': 1,
#   'golfe': 1,
#   'pareil': 1,
#   'cou': 1,
#   'tout': 1,
#   'renseignement': 1,
#   'tsar': 1,
#   'nom,': 1,
#   'Midi': 1,
#   'disait': 1,
#   'dire': 2,
#   'thé': 1,
#   'concert': 1,
#   'public.': 1,
#   'bras,': 1,
#   'divin': 1,
#   'vestibule,': 1,
#   'maître': 2,
#   'remerciai,': 1,
#   'bruit': 1,
#   'langoureux': 1,
#   'Bergotte': 1,
#   'nez': 2,
#   'résultat': 1,
#   'style.': 1,
#   'style,': 2,
#   'signe': 1,
#   'livre,': 2,
#   'style': 3,
#   'but': 1,
#   'rameau': 1,
#   'faux,': 1,
#   'causeur': 1,
#   'Maître': 1,
#   'chef': 2,
#   '«genre»': 1,
#   'génie,': 1,
#   'courant': 2,
#   'pouvoir,': 1,
#   'jeune': 1,
#   'renier': 1,
#   'vouloir': 2,
#   'Chateaubriand': 1,
#   'lait': 1,
#   'publier,': 1,
#   'fut,': 1,
#   'suffrage': 1,
#   'principe': 1,
#   'train': 1,
#   'mauvais': 1,
#   'juge': 2,
#   'vis': 1,
#   'bras': 4,
#   'mouvement': 1,
#   'diriger.': 1,
#   'pur': 1,
#   'doper!--Oui,': 1,
#   'jabot': 1,
#   'gilet': 2,
#   'moyen': 1,
#   'voyage': 1,
#   'danger': 1,
#   'peintre': 1,
#   'grain,': 1,
#   'mélange;': 1,
#   'gros': 1,
#   'ventre': 1,
#   'bien-être': 1,
#   'savais!»': 1,
#   'contentait': 1,
#   'reproduire?': 1,
#   '_niveau': 1,
#   'disais': 1,
#   'symptôme': 1,
#   'voir,': 1,
#   'lorgnon': 1,
#   'suppléer,': 1,
#   'sourcil': 1,
#   'médisant': 1,
#   'dites-vous?»': 1,
#   'yacht': 1,
#   'mien': 2,
#   'bouquet:': 1,
#   '«Monseigneur».': 1,
#   'résumé': 1,
#   'personnel': 1,
#   'regretterez': 1,
#   'sérieux': 1,
#   'manque': 1,
#   'contact': 1,
#   'dedans,': 1,
#   'seraient': 1,
#   'travail': 1,
#   'reçoive': 1,
#   'livre': 1,
#   '«leader': 1,
#   'Figaro.': 1,
#   'boston.': 1,
#   'paroxisme': 1,
#   'feignais,': 1,
#   'trouvant': 1,
#   'rire': 1,
#   'chagrin': 2,
#   'diriez.»': 1,
#   'courage': 1,
#   'détournerait': 1,
#   'plateau': 1,
#   'pouvaient': 1,
#   'spectacle': 1,
#   'simple': 1,
#   'dit:': 1,
#   'voudrais.': 1,
#   'courrier': 2,
#   'même,': 1,
#   'savais,': 1,
#   'jour.': 1,
#   'centre,': 1,
#   'passant': 1,
#   'passant,': 1,
#   'samovar--importation': 1,
#   'thé»,': 1,
#   'plus.': 1,
#   'secret,': 1,
#   '«five': 1,
#   'lendemain:': 1,
#   'ciel,': 1,
#   'dirait': 1,
#   'ministère.': 1,
#   'gouvernail,': 1,
#   'bien': 1,
#   'propose.»': 1,
#   'ferai': 1,
#   'ministère!': 2,
#   'Schisme.': 1,
#   'verrons': 1,
#   'faire,': 1,
#   '«monde»': 1,
#   'contraire.': 1,
#   'prix': 1,
#   'trompez': 1},
#  'regret': {'que': 1, 'mélancolique': 1, "qu'on": 1},
#  'que': {'le': 77,
#   'Swann,': 1,
#   'pour': 9,
#   "c'était": 25,
#   'la': 67,
#   'cela': 12,
#   'nos': 3,
#   'si': 20,
#   'nous': 60,
#   "s'il": 8,
#   'ses': 6,
#   'ces': 9,
#   'rien': 5,
#   'sans': 2,
#   'des': 9,
#   'sont': 2,
#   'de': 20,
#   'lui': 9,
#   'seul,': 1,
#   'Bismarck': 1,
#   'je': 211,
#   'ma': 12,
#   'quand,': 2,
#   'par': 14,
#   'les': 53,
#   '(de': 1,
#   "l'ami": 1,
#   "l'une;": 1,
#   "l'Ambassadeur": 1,
#   'M.': 12,
#   'cette': 21,
#   'ton': 1,
#   'tu': 10,
#   'mon': 18,
#   "j'allasse": 1,
#   "j'allais": 1,
#   'même': 1,
#   'Gilberte': 16,
#   'dans': 32,
#   "j'aurais": 11,
#   'sur': 2,
#   'ce': 39,
#   'certains': 1,
#   "j'avais": 53,
#   'celui': 8,
#   'devait': 1,
#   "l'idée": 2,
#   'selon': 2,
#   'mes': 14,
#   "j'étais": 15,
#   'notre': 3,
#   'son': 17,
#   "m'avaient": 2,
#   'sa': 7,
#   'commençât': 1,
#   'disent': 1,
#   "l'autre,": 2,
#   "j'eus,": 1,
#   'pouvait': 2,
#   'celle': 5,
#   'comme': 4,
#   "j'admirais": 2,
#   "j'entendais,": 1,
#   'recevait': 1,
#   'celles': 5,
#   'chez': 9,
#   "j'applaudissais,": 1,
#   'vous': 37,
#   'vous,': 3,
#   'font': 1,
#   'supportaient': 1,
#   'finir,': 1,
#   'moi,': 6,
#   "l'aveu": 2,
#   'toi': 1,
#   "j'aimais": 2,
#   'répéter': 2,
#   'tout': 9,
#   'fit': 2,
#   "c'est": 23,
#   'quand': 5,
#   'Sa': 1,
#   'celui-ci': 3,
#   'tels': 2,
#   'bien': 3,
#   'Vaugoubert,': 1,
#   'ceux-ci': 1,
#   'cela,': 2,
#   'précisément': 1,
#   'vingt': 1,
#   'vont': 1,
#   'Swann': 13,
#   'non': 2,
#   "d'amusement": 1,
#   "l'enlèvement": 1,
#   'leur': 8,
#   'tous': 1,
#   'telle': 1,
#   'ne': 5,
#   'finit': 1,
#   'si,': 4,
#   'pourtant,': 1,
#   'dira': 1,
#   'représentent': 1,
#   'plus': 2,
#   'généralement': 1,
#   'celle-ci': 4,
#   'personne': 3,
#   'rendrait': 1,
#   'ceux': 3,
#   "j'appelle": 1,
#   "d'agencer": 1,
#   'cela!': 1,
#   "j'y": 5,
#   "d'être": 2,
#   "j'ai": 4,
#   'moral,': 1,
#   'prend': 1,
#   'moi.': 2,
#   "quelqu'un": 1,
#   "j'eus": 2,
#   "l'autre": 2,
#   'mènent': 1,
#   'soucieuse': 1,
#   'grâce': 1,
#   '(alors': 1,
#   'chaque': 4,
#   'maman': 3,
#   'Mme': 21,
#   'nulle': 1,
#   'Maman': 1,
#   'ça': 6,
#   'naturel': 1,
#   'dès': 2,
#   "j'oubliais": 1,
#   "j'espérais": 1,
#   'surviendrait': 1,
#   'du': 7,
#   'lui,': 1,
#   'vint': 1,
#   '«le': 2,
#   "d'habitude,": 2,
#   "m'avouer": 1,
#   'prouver': 1,
#   "d'après": 1,
#   "l'aspect": 1,
#   'prennent': 1,
#   'venaient': 1,
#   'Françoise': 1,
#   "j'eusse": 3,
#   'me': 3,
#   "l'on": 3,
#   'Cottard,': 1,
#   'cet': 4,
#   'frapper': 1,
#   'vos': 1,
#   'toutes': 3,
#   'peuvent': 1,
#   'depuis': 2,
#   "l'amant": 1,
#   "l'amour.": 1,
#   'toute': 4,
#   "j'en": 7,
#   'tandis': 1,
#   'jadis': 1,
#   'fût': 4,
#   'tel': 1,
#   "j'atteignisse": 1,
#   'devant': 2,
#   'momentanée.': 1,
#   'diraient': 1,
#   'chère': 1,
#   'Colombin,': 1,
#   "j'usasse": 1,
#   'possèdent': 1,
#   '«mettre': 1,
#   'madame': 1,
#   'toi,': 1,
#   "l'ancien": 1,
#   'pouvait,': 1,
#   "l'impossibilité": 1,
#   'sir': 1,
#   'nuit': 1,
#   '(par': 1,
#   'continuant': 1,
#   'jamais': 1,
#   'naturel.': 1,
#   "d'approfondir": 1,
#   "l'hypothèse": 1,
#   'là.': 1,
#   'seule': 1,
#   'désormais': 1,
#   'deux.': 1,
#   'Christmas,': 1,
#   'commençait': 1,
#   "l'heure.": 1,
#   'possédait': 1,
#   'spirituel.': 1,
#   "l'œuvre": 3,
#   'Madame': 2,
#   "m'apportait": 1,
#   'confusion': 1,
#   'peu': 1,
#   "l'artiste--et": 1,
#   'suit': 1,
#   '(comme': 1,
#   "d'y": 1,
#   'monsieur': 1,
#   'moi.--Allons,': 1,
#   'peut-être': 1,
#   "j'observais": 1,
#   'moi': 2,
#   "d'habitude.--Mais": 1,
#   "l'amour": 1,
#   'baignait': 1,
#   'sachant': 1,
#   'passaient': 1,
#   "j'ignorais.": 1,
#   "l'empereur": 1,
#   'ponctuer': 1,
#   "l'individu": 1,
#   'Gilberte,': 1,
#   'réunissant': 1,
#   'se': 4,
#   'pénétrait': 1,
#   'quelque': 2,
#   "n'avait": 1,
#   'beaucoup': 2,
#   'vide': 1,
#   "l'oreille": 1,
#   'Bergotte': 6,
#   '«plus': 1,
#   'doublement': 1,
#   "l'ordonnance": 1,
#   "l'auteur": 1,
#   "d'autres": 1,
#   "l'Académie": 1,
#   "d'une": 2,
#   "d'autre": 1,
#   "s'ils": 1,
#   'certaines': 1,
#   "c'étaient": 1,
#   'fut': 1,
#   'chacun': 1,
#   'celui-ci,': 1,
#   'Norpois': 1,
#   'superficiel,': 1,
#   'donnerait': 1,
#   "l'une": 1,
#   "l'une,": 1,
#   'parla': 1,
#   'puisque': 1,
#   "m'avait": 3,
#   "l'ennui": 1,
#   'cela!»': 1,
#   'Bloch': 1,
#   'contrairement': 1,
#   "j'aperçus": 1,
#   "j'entendais": 2,
#   'verser': 1,
#   'quelques': 2,
#   'désireux': 1,
#   'celui,': 1,
#   "l'intelligence": 1,
#   "d'heureuse": 1,
#   'trouve': 1,
#   "n'ayant": 1,
#   "d'habitude.": 1,
#   'souri': 1,
#   'cerne': 1,
#   "j'attendais": 1,
#   'décrivait': 1,
#   "l'adolescence,": 1,
#   'cacherait': 1,
#   'tant': 1,
#   'durant': 1,
#   'prolonger': 1,
#   'bientôt': 1,
#   '(afin': 1,
#   'malgré': 1,
#   'décidé': 1,
#   'longtemps': 1,
#   'nous,': 1,
#   "j'entrasse": 1,
#   'nuancer': 1,
#   'faillir': 1,
#   'Debac.--Moi': 1},
#  'Professeur': {'Cottard': 2, 'Cottard,': 1, 'leur': 1},
#  'Cottard': {'fût': 1,
#   'bien': 1,
#   'au': 2,
#   'était': 1,
#   'montrait': 1,
#   'furent': 1,
#   'restant': 1,
#   'et': 5,
#   'toute': 1,
#   'en': 1,
#   'eurent': 1,
#   'du': 1,
#   'disait:': 1,
#   'qui': 2,
#   'que': 2,
#   'vous': 1,
#   'puisse': 1,
#   'me': 1},
#  'en': {'voyage': 1,
#   'matière': 3,
#   'continuant': 1,
#   'commun': 2,
#   'général,': 1,
#   'œuvre': 1,
#   'revanche': 3,
#   'effet': 8,
#   'ce': 14,
#   'Égypte,': 1,
#   'méritant': 1,
#   'faisant': 5,
#   'garde,': 1,
#   'cela': 5,
#   'mesure': 1,
#   'effet,': 12,
#   'particulier,': 1,
#   'apparence,': 2,
#   'dehors': 6,
#   'est': 4,
#   'le': 3,
#   'prendre': 2,
#   'redressant': 1,
#   'voiture,': 1,
#   'envoyer': 1,
#   'ville': 2,
#   '«matinée»,': 1,
#   'moi': 9,
#   'remarquant': 1,
#   'renonçant': 1,
#   'sortant': 1,
#   'pensant': 3,
#   'noir': 1,
#   'pleine': 3,
#   'vogue;': 1,
#   'vous': 4,
#   'fin': 2,
#   'être': 2,
#   'cédant': 2,
#   'voie': 1,
#   'chapeau,': 1,
#   'se': 12,
#   'scène': 1,
#   'descendrait': 1,
#   'entend': 1,
#   'soirée,': 2,
#   'train': 4,
#   'colère,': 1,
#   'faveur': 2,
#   'velours': 1,
#   'prenant': 1,
#   'ouvrant': 2,
#   'froissant': 1,
#   'applaudissant': 1,
#   'ne': 3,
#   'même': 9,
#   'recueillir': 1,
#   'préparatifs': 1,
#   'eux': 3,
#   'applaudissements,': 1,
#   'juger': 1,
#   'lisant,': 1,
#   'tâchant': 2,
#   'danger,': 1,
#   'me': 16,
#   'or,': 1,
#   'un': 4,
#   'rentrant': 2,
#   'disponibilité,': 1,
#   'tournée.': 1,
#   'souriant': 3,
#   'vertu': 2,
#   'mains': 1,
#   'face': 3,
#   'route,': 1,
#   'gros': 1,
#   'elles-mêmes,': 1,
#   'feuilleton.': 1,
#   'prose': 2,
#   'revenant': 1,
#   'elle-même': 1,
#   'avions': 1,
#   'répondant': 1,
#   'quoi': 3,
#   'profiter': 1,
#   'Angleterre': 2,
#   'Amérique,': 1,
#   'musicienne!': 1,
#   'citant': 1,
#   'rien': 8,
#   "s'esclaffant": 1,
#   'politique': 1,
#   'restant': 2,
#   'reprit,': 1,
#   'disant': 4,
#   "m'apercevant": 1,
#   "s'adressant": 4,
#   'faire': 2,
#   'parlait,': 1,
#   'souffrir,': 1,
#   'serait': 1,
#   'attendant': 3,
#   'détachant': 1,
#   'vaut': 1,
#   'resserrant': 2,
#   'lisant': 1,
#   "l'art": 1,
#   'relief': 2,
#   'somme': 5,
#   'la': 4,
#   'Espagne,': 1,
#   'partie': 2,
#   'jetant': 1,
#   'véritable': 1,
#   'relations': 1,
#   'règle': 1,
#   'fissent': 1,
#   'fait': 2,
#   'croire': 1,
#   'avons': 1,
#   'avait': 6,
#   'raison': 1,
#   'celui-ci,': 1,
#   'lui,': 1,
#   'lui': 5,
#   'consolidant': 1,
#   'vue': 3,
#   'artiste,': 1,
#   'corrompu,': 1,
#   'tous': 2,
#   'pratiquent': 1,
#   'raconte': 1,
#   'énonçant': 1,
#   'jouir.': 1,
#   'cherchant': 1,
#   'Swann,': 1,
#   'fixant': 3,
#   'fut.': 1,
#   'bas': 1,
#   'joue': 1,
#   'toute': 2,
#   'présence,': 1,
#   'odeur': 1,
#   'ma': 1,
#   'grandissant': 1,
#   'visite,': 1,
#   'les': 3,
#   'perspective': 1,
#   'soi-même,': 1,
#   'ajoutant': 2,
#   'tâtant': 1,
#   'ces': 2,
#   'a': 5,
#   'eux-mêmes': 1,
#   'repensant': 1,
#   "l'amour": 1,
#   'parlant': 5,
#   'suivre': 1,
#   'accélérant': 1,
#   'deux': 2,
#   'moins': 1,
#   'partie,': 1,
#   'était': 1,
#   'ramassait': 1,
#   'arrière...»': 1,
#   'fissions': 1,
#   'plein': 2,
#   'somme,': 1,
#   'tirer': 1,
#   'vain;': 1,
#   'écrire': 1,
#   'éveiller': 1,
#   'elle.': 1,
#   'dormant,': 1,
#   'désaccord': 1,
#   'seize': 1,
#   'disant:': 3,
#   'supporter': 1,
#   'France,': 1,
#   'voici': 1,
#   'roulant': 1,
#   'leur': 2,
#   'lui;': 1,
#   'doute': 1,
#   'bonne': 1,
#   'état': 1,
#   'détresse': 1,
#   'son': 1,
#   'présence': 1,
#   'cas': 1,
#   'moi,': 3,
#   'lavant': 1,
#   'venant': 1,
#   'pensées,': 1,
#   'cachette': 1,
#   'coquillages': 1,
#   'vain': 4,
#   'avoir': 5,
#   'visiteur': 1,
#   'trouva': 1,
#   'une': 3,
#   'soulevant': 1,
#   'descendant': 1,
#   'posséder': 2,
#   'anglais': 3,
#   'travers': 1,
#   'caractères': 1,
#   'noir,': 1,
#   'forme': 3,
#   'contenait': 1,
#   'majuscules': 1,
#   'bois,': 1,
#   'général': 1,
#   'chocolat': 1,
#   'admettant': 1,
#   'courant,': 1,
#   'satin': 1,
#   'tant': 1,
#   'sens': 1,
#   'beauté': 1,
#   'culotte': 1,
#   'voyant': 2,
#   "n'ayant": 2,
#   'fût': 1,
#   'parlait': 1,
#   'mains.': 1,
#   'exceptant': 1,
#   'usait': 1,
#   'plus': 3,
#   'y': 3,
#   'amènera': 1,
#   'conviant': 1,
#   'connaissait': 1,
#   'temps,': 1,
#   'visite': 1,
#   'amena': 1,
#   'bas,': 1,
#   'France».': 1,
#   'ses': 2,
#   'soupçonner,': 1,
#   'jouant': 1,
#   'cachette.': 1,
#   'avaient': 1,
#   'grade,': 1,
#   'a-t-il': 1,
#   "s'attachant": 1,
#   'groupant': 1,
#   'réunissant': 1,
#   'riant': 3,
#   'rougissant': 1,
#   'exciter': 1,
#   'réserve': 1,
#   'Odette,': 1,
#   'telle': 1,
#   'promenade': 1,
#   'large': 1,
#   'faisait': 2,
#   'compagnie': 1,
#   'entendant': 1,
#   'croyant': 1,
#   'avance.»': 1,
#   'agitant': 1,
#   'livrée,': 1,
#   'crêpe': 2,
#   'dormant': 1,
#   'enfance': 1,
#   'fournir': 1,
#   'elle': 3,
#   'dernier.': 1,
#   'réalité': 1,
#   'fécondant': 1,
#   'réserve,': 1,
#   'tenir': 1,
#   'exclut': 1,
#   'étant': 4,
#   'catalepsie.': 1,
#   'soi»': 1,
#   'redingote': 2,
#   'ethnographie': 1,
#   'revenir': 1,
#   "m'efforçant": 1,
#   'nous.': 1,
#   'exprimer': 1,
#   'cela;': 1,
#   'amie': 1,
#   'mariage': 1,
#   'prononçant': 1,
#   'manteau.--Il': 1,
#   'place.': 1,
#   "l'ouvrant": 1,
#   'colimaçon': 2,
#   'colimaçon;': 1,
#   'partant': 1,
#   'de': 1,
#   'eût': 1,
#   'faire,': 1,
#   'sont': 1,
#   'rapport': 1,
#   'donner': 1,
#   'rappeler': 1,
#   'action': 1,
#   'négligeant': 1,
#   'lumière,': 1,
#   'propre,': 1,
#   'quelque': 4,
#   'écoutant': 1,
#   'clameurs': 1,
#   'force': 1,
#   'témoignant': 1,
#   'employant': 1,
#   'construisant': 1,
#   'verra': 1,
#   'eux,': 1,
#   'relation': 1,
#   'châle': 1,
#   'étaient': 1,
#   'tirèrent': 1,
#   'Bergotte': 1,
#   "l'esprit": 1,
#   'disgrâce.': 1,
#   'Gilberte': 2,
#   'vénitienne.': 1,
#   'souvenir': 1,
#   'mari': 1,
#   'elle;': 1,
#   'faute': 1,
#   'cachant': 1,
#   'particulier': 2,
#   'revanche,': 1,
#   'voiture': 1,
#   'consultant': 1,
#   'soi-même': 1,
#   'silence.': 1,
#   'rose': 1,
#   'apparaissait': 1,
#   'caressant': 1,
#   'attachant': 1,
#   'tout.': 1,
#   'vidant': 1,
#   'possibilités': 1,
#   "m'en": 1,
#   'proposait': 1,
#   'vantant': 1,
#   'donnai': 1,
#   'apparence': 2,
#   'recevant': 1,
#   'sa': 1,
#   'voulus,': 1,
#   "m'embrassant:": 1,
#   'passant': 1,
#   'venir': 1,
#   'ôtant': 1,
#   'larmes.': 1,
#   'temps': 1,
#   'nous': 2,
#   'dignes': 1,
#   'projetant': 1,
#   'débutant': 1,
#   'protestant': 1,
#   'retrouverait-elle': 1,
#   'vain:': 1,
#   'mer': 1,
#   'créant': 1,
#   'allant': 1,
#   'mouvement;': 1,
#   'contraste': 1,
#   'saluant': 1,
#   'ont': 1,
#   'robe': 1,
#   'chemise': 1,
#   'enlevant': 1,
#   'nous-mêmes,': 1,
#   'voir': 1,
#   'saluts,': 1,
#   'cuisine.': 1,
#   'visite.': 1,
#   'ait': 1,
#   'riant.': 1},
#  'voyage': {'et': 2, 'à': 3, 'dont': 1, 'deux': 1, "qu'ils": 1},
#  'et': {"qu'elle-même": 1,
#   "l'autre": 1,
#   "d'un": 4,
#   'la': 25,
#   'aussi': 7,
#   'par': 14,
#   'même': 9,
#   'que,': 4,
#   'celle-là': 1,
#   'sans': 11,
#   'les': 25,
#   'non': 12,
#   'ma': 5,
#   'posséder': 1,
#   'eussent': 1,
#   'moustaches.': 1,
#   'ambassadeur': 1,
#   'auxquels': 2,
#   'bénéficiaient': 1,
#   'de': 76,
#   'qui': 53,
#   'le': 22,
#   'à': 31,
#   'du': 10,
#   'M.': 1,
#   'Deschanel,': 1,
#   'où': 16,
#   "l'avouait": 1,
#   "d'où": 2,
#   'nulle.': 1,
#   'que': 47,
#   'cette': 4,
#   'tenait': 1,
#   "d'être": 1,
#   "d'une": 6,
#   'ses': 9,
#   'je': 24,
#   'abandonnés': 1,
#   'garder': 1,
#   'ne': 26,
#   'blanc': 1,
#   "l'ensoleillement": 1,
#   'unique': 1,
#   'vulgaire.': 1,
#   'ce': 8,
#   'des': 14,
#   'tout': 5,
#   'faisait': 1,
#   "j'avais": 1,
#   'aux': 3,
#   "n'était": 5,
#   'sur': 6,
#   "j'aurais": 2,
#   'desquelles': 3,
#   "c'était": 1,
#   'derrière': 1,
#   'jour,': 1,
#   'légers': 1,
#   'pour': 17,
#   'en': 27,
#   'mon': 4,
#   'dans': 8,
#   '«mythe': 1,
#   'moi': 5,
#   'sachant': 1,
#   'venues': 2,
#   "New-York--qu'elle": 1,
#   "qu'on": 7,
#   'dont,': 1,
#   'purement': 1,
# ...
#   'puissances': 1,
#   'mains.': 1,
#   'adversaires': 1,
#   'pays,': 1,
#   'poids': 1,
#   'mesures).': 1,
#   'minutes.': 1,
#   'cherchaient': 1,
#   'fois': 3,
#   'raisons': 1,
#   '«commen': 1,
#   'personnes': 3,
#   'visites': 2,
#   'ans.': 1,
#   'événements': 1,
#   'femmes': 1,
#   'manières': 1,
#   'figures': 1,
#   'états': 1,
#   'était': 1,
#   'autres': 1,
#   'brides.': 1,
#   'seulement.': 1,
#   'prières,': 1,
#   'invités': 1,
#   'peut': 1,
#   'heures.': 1,
#   'grains': 1,
#   'natures': 1,
#   'qualités': 1,
#   'sœurs,': 1,
#   'sœurs': 1,
#   'Gilbertes.': 1,
#   'natures,': 1,
#   'autres.': 1,
#   'était-elle': 1,
#   'raisons.': 1,
#   'à': 1,
#   'pas': 1,
#   'plateaux': 1,
#   'optiques': 1,
#   'vagues,': 1,
#   'intailles': 1},
#  'pays': {'se': 1, 'et': 1, 'à': 1, 'de': 1},
#  'résument,': {'se': 1},
#  'traduisent,--dans': {'un': 1},
#  'discours,': {'dans': 1, 'et': 1, 'de': 1},
#  'adjectif,': {'banal': 1},
#  'banal': {'en': 1},
#  'apparence,': {'mais': 1, 'que': 1},
#  'voient': {'tout': 1, 'plus': 1},
#  'passait': {'pour': 1, 'en': 1, 'à': 1, 'au': 1, 'sa': 1, 'pas': 1},
#  'très': {'froid': 1,
#   'lié': 1,
#   'élevé,': 1,
#   'sûr,': 1,
#   'délicat,': 1,
#   'fin».': 1,
#   'bien....': 1,
#   'bien,': 4,
#   'nettement,': 1,
#   'en': 1,
#   'flattées.': 1,
#   'satisfaite': 1,
#   'différent': 1,
#   'fin.': 1,
#   'rapidement:': 1,
#   'bon': 1,
#   'tard': 1,
#   'souffrant': 1,
#   'grand': 1,
#   'souvent': 1,
#   'liée': 1,
#   'ennuyeux.': 1,
#   'loin': 2,
#   'rouge,': 1,
#   'répandue': 1,
#   'courtes': 1,
#   '«fast»': 1,
#   'à': 1,
#   'bien;': 1,
#   'vraisemblablement,': 1,
#   'brillants,': 1,
#   'fort': 3,
#   'mal': 1,
#   'vives,': 1,
#   'bien': 3,
#   'aimable': 1,
#   'intelligente,': 1,
#   '«pushing»,': 1,
#   'beau': 1,
#   'humiliant': 1,
#   'drôle!': 1,
#   'souffrante': 1,
#   'drôles': 1,
#   'noble': 1,
#   'plaisir': 1,
#   'fier': 1,
#   'mauvaise': 1,
#   'agréable,': 1,
#   'passionnés': 1,
#   'bienveillant,': 1,
#   'tard,': 1,
#   'bas': 1,
#   'imbue': 1,
#   'haut': 1,
#   'rarement': 1,
#   'facile...': 1,
#   'bienveillante': 1},
#  'froid': {'à': 1,
#   'aux': 1,
#   'et': 2,
#   'peut': 1,
#   'que': 1,
#   'leur': 1,
#   'souci': 1},
#  'Commission,': {'où': 1, 'et': 1},
#  'siégeait': {'à': 1},
#  'côté': {'de': 18,
#   'avec': 1,
#   "d'elle.": 1,
#   "d'elle,": 3,
#   'droit,': 1,
#   "d'une": 1,
#   'sur': 1,
#   'statique': 1,
#   'essentiel.': 1,
#   "d'elle": 1,
#   'des': 2,
#   'du': 2,
#   'cosmique': 1,
#   'où': 1,
#   'pour': 1},
#  'chacun': {'félicitait': 1,
#   'se': 2,
#   'agit': 1,
#   'de': 1,
#   'pourtant': 1,
#   'était': 1,
#   'un': 1,
#   'dans': 1,
#   'appelant': 1,
#   'des': 1,
#   'a': 1,
#   'et': 1},
#  'félicitait': {'celui-ci': 1},
#  "l'amitié": {'que': 1, 'et': 1},
#  'témoignait': {"l'ancien": 1, 'aucune': 1},
#  'ambassadeur.': {'Elle': 1},
#  'Elle': {'étonnait': 1,
#   'fut': 1,
#   'est': 2,
#   'avait': 5,
#   'lui': 2,
#   "n'était": 1,
#   'se': 2,
#   "l'aurait": 1,
#   "n'apprendrait": 1,
#   'disait': 1,
#   'y': 1,
#   'le': 1,
#   'la': 1,
#   'me': 2,
#   'grignotait,': 1,
#   'sera': 1,
#   'en': 1,
#   "n'avait": 1,
#   'ne': 1,
#   'maudissait': 1,
#   'et': 1,
#   "n'a": 1,
#   'allait': 1,
#   "s'excusait": 1,
#   "n'en": 1,
#   'a': 1,
#   'prit': 1,
#   'repose': 1,
#   'sentit': 1,
#   "s'en": 1,
#   "s'imaginait": 1},
#  'étonnait': {'mon': 1},
#  'premier.': {'Car': 1},
#  'Car': {'étant': 1,
#   'quand': 2,
#   'la': 4,
#   'Swann': 1,
#   "j'avais": 1,
#   'que': 1,
#   "m'approchant": 1,
#   'ce': 1,
#   'maître': 1,
#   "s'il": 2,
#   'mon': 1,
#   'ces': 1},
#  'généralement': {'peu': 1,
#   'les': 1,
#   'plus': 1,
#   'que': 1,
#   'par': 1,
#   "qu'on": 1,
#   'un': 1},
#  'peu': {'aimable,': 2,
#   '«vieux': 1,
#   'désuète': 1,
#   'fort,': 1,
#   'avec': 1,
#   'mes': 1,
#   'si': 1,
#   'sûres,': 1,
#   'délicat,': 1,
#   'frêle,': 1,
#   'près': 4,
#   'de': 23,
#   'inégale': 1,
#   'hardi': 1,
#   'usitée': 1,
#   'à': 8,
#   'toute': 1,
#   'pour': 2,
#   'trop.': 1,
#   'entendu': 1,
#   'plus': 5,
#   'officielle': 1,
#   "qu'il": 1,
#   'viril.': 1,
#   'haute,': 1,
#   'vue,': 1,
#   'probable': 1,
#   '«poncif»': 1,
#   'voir,': 1,
#   'faire': 1,
#   'en': 2,
#   'pauvre': 1,
#   'scrupuleux': 1,
#   'installés,': 1,
#   'rouge,': 1,
#   "d'air": 1,
#   'tranquille,': 1,
#   'marquantes': 1,
#   'solennel,': 1,
#   'sommaire,': 1,
#   'composite': 1,
#   'élégante': 1,
#   'envieux': 1,
#   "qu'elle": 1,
#   'ridicule,': 1,
#   'et,': 1,
#   'profonde,': 1,
#   'exclusive': 1,
#   'avant,': 1,
#   '«toc»,': 1,
#   'lâche': 1,
#   'maussade,': 1,
#   'fruste': 1,
#   '«chic»,': 1,
#   'ressemblants': 1,
#   'après': 1,
#   'folle».': 1,
#   'trop': 1,
#   'vulgaires,': 1,
#   'insensé': 1,
#   'Mme': 2,
#   'nobles.': 1,
#   'vrai': 1,
#   'digne,': 1,
#   'honorable': 1,
#   'renouvelé': 1,
#   'et': 1,
#   'consolé': 1,
#   'sont': 1,
#   'tard.»': 1,
#   'dans': 1,
#   'tard,': 1,
#   'appropriés': 1},
#  'aimable,': {'il': 1, 'qui': 1},
#  "l'habitude": {'de': 10, 'que': 1, 'hors': 1, 'commune': 1, 'personne': 1},
#  "n'être": {'pas': 1, 'plus': 1},
#  'dehors': {'du': 3,
#   'de': 2,
#   'et': 2,
#   'des': 1,
#   'interposaient': 1,
#   "d'une": 1,
#   'vers': 1},
#  'cercle': {'de': 1, 'choisi': 1, "d'assiettes": 1},
#  "l'avouait": {'avec': 1},
#  'simplicité.': {'Il': 1, 'Je': 1},
#  'conscience': {"qu'il": 1, 'de': 3},
#  'avances': {'du': 1},
#  'diplomate,': {'un': 1, 'et': 1},
#  'effet': {'de': 2,
#   'à': 2,
#   'entendre': 1,
#   'le': 1,
#   'plaisant,': 1,
#   'un': 1,
#   'chaque': 1,
#   'dès': 1},
#  'vue': {'tout': 1,
#   'des': 1,
#   'me': 1,
#   'que': 1,
#   'de': 4,
#   'pendant': 1,
#   'annoncée': 1,
#   'plus': 2,
#   'personnel,': 1,
#   "d'où": 1,
#   '(car': 1},
#  'place': {'pour': 1,
#   'des': 2,
#   'où': 2,
#   'était': 1,
#   'et': 1,
#   'au': 1,
#   'dans': 2,
#   'infime': 1,
#   'Gaillon': 1,
#   'successivement': 1,
#   'duquel': 1,
#   "n'était": 1,
#   'livré': 1,
#   'avait': 1,
#   'de': 1,
#   'plus': 1},
#  'décider': {'de': 1, "s'il": 1, 'ce': 1, 'à': 1},
#  'sympathies,': {'et': 1},
#  "d'où": {'toutes': 1,
#   "l'homme": 1,
#   'ce': 1,
#   'dépassait': 1,
#   'possibilité': 1,
#   'une': 1,
#   "s'envole": 1,
#   'lui': 1,
#   "l'on": 1},
#  'toutes': {'les': 34,
#   'récentes,': 1,
#   'ces': 7,
#   'leurs': 2,
#   'mes': 2,
#   'faites,': 1,
#   'façons': 1,
#   'choses.': 1,
#   'celles': 1,
#   'pareilles;': 1,
#   'plongées': 1,
#   'relations': 1,
#   'au': 1,
#   'comme': 1,
#   'était': 1,
#   'choses': 1},
#  'qualités': {'intellectuelles': 1,
#   'que': 1,
#   'matérielles': 1,
#   'du': 1,
#   'et': 1,
#   'qui': 1},
#  'intellectuelles': {'ou': 1},
#  'sensibilité': {"d'une": 1, 'plus': 1, 'profonde.': 1},
#  'personne': {'ne': 5,
#   'vénérable': 1,
#   'digne': 1,
#   "n'y": 1,
#   'qui': 6,
#   'supplémentaire,': 1,
#   'dont': 1,
#   'là,': 1,
#   'le': 1,
#   'de': 2,
#   'que': 2,
#   'vivante': 1,
#   'avec': 3,
#   "n'aurait": 1,
#   "qu'elle": 1,
#   'déclare': 1,
#   'dans': 1,
#   'comme': 1,
#   'parce': 1,
#   'mais': 1,
#   'du': 1,
#   'ce': 1,
#   "qu'on": 1,
#   'nous': 1,
#   'plus': 1},
#  'auprès': {'de': 14,
#   "d'une": 1,
#   'du': 1,
#   'des': 2,
#   "d'elle.": 2,
#   "d'amis": 1,
#   "d'eux,": 1,
#   "d'elle.»": 1,
#   "d'elle-même.": 1},
#  'ennuie': {'ou': 1, 'avec': 1},
#  'agace': {'une': 1},
#  'recommandation': {'que': 1},
#  'rondeur': {'et': 1},
#  'gaieté': {"d'une": 1},
#  'vide,': {'frivole': 1,
#   'ils': 1,
#   'que': 1,
#   'de': 1,
#   'ne': 1,
#   'tant': 1,
#   'et': 1},
#  'frivole': {'et': 2},
#  'nulle.': {'«De': 1},
#  '«De': {'Norpois': 1},
#  'invité': {'de': 2, 'sans': 1, 'par': 1, 'pour': 1},
#  'nouveau': {'à': 3,
#   'qui': 2,
#   'venu': 1,
#   'il': 1,
#   'où': 1,
#   'monde': 1,
#   'et': 1,
#   'régime': 1,
#   'bruit': 1,
#   'pour': 2,
#   'point': 1},
#  'dîner;': {"c'est": 1, 'tu': 1},
#  'extraordinaire;': {'tout': 1},
#  'monde': {'en': 1,
#   'et': 6,
#   'plus': 1,
#   'pensait': 1,
#   'républicain': 1,
#   "s'étonna": 1,
#   'ignore': 1,
#   "qu'une": 1,
#   'des': 1,
#   'nouveau': 1,
#   'où': 1,
#   'mystérieux.': 1,
#   'parle': 1,
#   'près': 1,
#   'qui': 1,
#   'sont': 1,
#   'chez': 1,
#   'était': 1,
#   'infiniment': 1,
#   'dit': 1,
#   "d'un": 1,
#   'savait': 1,
#   'imaginé,': 1,
#   'visible': 1,
#   'vrai,': 1,
#   'vu': 1,
#   'imaginé).': 1,
#   'se': 1,
#   "s'est": 1,
#   'de': 1,
#   '(sans': 1,
#   'ne': 1,
#   'sous': 1,
#   'est': 1,
#   'pour': 1,
#   'capable': 1,
#   "s'incline,": 1,
#   'serait': 1,
#   'assommant': 1,
#   'que,': 1},
#  'stupéfait': {'à': 1, "d'apprendre": 1},
#  'Commission': {'où': 1, 'après': 1, 'tout': 1},
#  "n'a": {'de': 2,
#   'certes': 1,
#   'pas': 9,
#   'jamais': 3,
#   'vu': 1,
#   'que': 1,
#   'pu': 1,
#   'rien': 2,
#   'pour': 1,
#   "qu'à": 1,
#   'plus': 1},
#  'privées': {'avec': 1},
#  'personne.': {'Je': 1, 'Un': 1, 'Ensuite': 1},
#  'Je': {'suis': 4,
#   'sais': 3,
#   'les': 2,
#   'me': 9,
#   'mettais': 1,
#   'fus': 1,
#   'ne': 20,
#   "l'écoutais": 1,
#   'dis': 1,
#   'pensais': 2,
#   'reposai': 1,
#   "n'en": 2,
#   'lui': 6,
#   'voulus': 1,
#   "l'avais": 3,
#   "n'ai": 2,
#   "n'avais": 2,
#   'serais': 1,
#   'démêlai': 1,
#   "n'irai": 1,
#   'craignais': 2,
#   'trouve': 2,
#   "n'entends": 1,
#   'crois': 4,
#   'vous': 4,
#   'compris': 2,
#   'revins': 2,
#   'venais': 2,
#   'continuai': 1,
#   'mentirais': 1,
#   'trouvais': 1,
#   'sentais': 1,
#   'dus': 1,
#   "l'aperçus": 1,
#   'tâchais': 3,
#   'protestais': 1,
#   "l'embrassai": 1,
#   'trouvai': 2,
#   'vis': 3,
#   'pus': 1,
#   'conclus': 1,
#   "l'ouvris": 1,
#   'voyais': 1,
#   'croyais': 1,
#   'la': 2,
#   'vais': 2,
#   "m'étais": 1,
#   'continuais': 1,
#   'rayonnais': 1,
#   'voulais': 1,
#   'soufflai': 1,
#   "l'ai": 1,
#   'suppliai': 1,
#   'reconnais': 1,
#   'doutais': 1,
#   'sentis': 1,
#   "l'entendais": 1,
#   "l'ouvris,": 1,
#   'cessai': 1,
#   'le': 1,
#   'respirais': 1},
#  'suis': {'sûr': 1,
#   'amusé': 1,
#   'pas': 3,
#   'naturellement': 1,
#   'laissé': 1,
#   "d'autant": 1,
#   'ennemi': 1,
#   'ravie': 1,
#   'rentré': 1,
#   'dans': 1,
#   'aussi': 1,
#   'absolument': 1,
#   'si': 1,
#   'désolé': 1,
#   'libre,': 1,
#   'obligée,': 1,
#   'sûre': 1,
#   'une': 1,
#   'bien': 1,
#   'heureuse': 1},
#  'sûr': {"qu'il": 1, 'de': 2, "qu'elle": 1},
#  'va': {'encore': 1,
#   'pas': 2,
#   'être': 2,
#   'surtout': 1,
#   'pleuvoir': 1,
#   'dire': 1,
#   'vous': 1,
#   'dans': 1,
#   'madame': 1,
#   'entrer': 1,
#   'lui': 1,
#   'pouvoir': 1,
#   'pas;': 1},
#  'raconter': {'des': 1, 'à': 1, 'mes': 1},
#  'palpitantes': {'sur': 1},
#  '70.»': {'Mon': 1},
#  'Mon': {'père': 4,
#   'plaisir': 1,
#   'père,': 2,
#   'intérêt': 1,
#   'amour': 1,
#   'imagination': 1,
#   'Dieu': 3,
#   'pauvre': 1,
#   'admiration': 1,
#   'mari': 1},
#  'savait': {'que': 3,
#   'alors': 1,
#   "qu'il": 1,
#   'exactement': 1,
#   'bien': 1,
#   'pas': 2,
#   "d'ailleurs": 1,
#   "qu'une": 1,
#   'le': 1,
#   'à': 1,
#   "qu'elle": 1,
#   "l'anglais,": 1,
#   'aussi,': 1,
#   'et': 1},
#  'seul,': {'peut-être,': 1, 'une': 1, 'ou': 1, "qu'un": 1},
#  'averti': {"l'Empereur": 1, 'en': 1},
#  "l'Empereur": {'de': 1, 'je': 1},
#  'puissance': {'grandissante': 1, 'de': 2},
#  'grandissante': {'et': 1},
#  'intentions': {'belliqueuses': 1, 'de': 1},
#  'belliqueuses': {'de': 1},
#  'Prusse,': {'et': 1},
#  'Bismarck': {'avait': 1, 'est': 1, 'admirait': 1},
#  'intelligence': {'une': 1,
#   'des': 1,
#   'se': 1,
#   'devait': 1,
#   'sur': 1,
#   'que': 1,
#   'et': 2},
#  'estime': {'particulière.': 1},
#  'particulière.': {'Dernièrement': 1},
#  'Dernièrement': {'encore,': 1},
#  'encore,': {'à': 1,
#   'et': 1,
#   'dans': 2,
#   'artistes,': 1,
#   'de': 1,
#   'où': 1,
#   "jusqu'à": 1,
#   'celui': 1,
#   'mes': 1,
#   'parce': 1,
#   'comme': 1},
#  "l'Opéra,": {'pendant': 1},
#  'gala': {'offert': 1, 'du': 1},
#  'offert': {'au': 1},
#  'roi': {'Théodose,': 2,
#   'qui': 1,
#   'Théodose': 2,
#   'se': 2,
#   'Théodose.': 1,
#   'Théodose;': 1,
#   'du': 1,
#   'mage,': 1},
#  'Théodose,': {'les': 1, 'lui': 1, 'toute': 1},
#  'journaux': {'avaient': 1, 'après': 1, 'et': 1},
#  'remarqué': {"l'entretien": 1},
#  "l'entretien": {'prolongé': 1},
#  'prolongé': {'que': 1},
#  'souverain': {'avait': 1, 'de': 1},
#  'accordé': {'à': 1},
#  '«Il': {'faudra': 1, 'est': 1, "n'y": 1, 'me': 2, 'a': 1},
#  'faudra': {'que': 2},
#  'sache': {'si': 1, 'bien': 1, 'seulement': 1},
#  'Roi': {'a': 1, 'de': 1},
#  'a': {'vraiment': 1,
#   'cité': 1,
#   'une': 9,
#   'été': 10,
#   'publié': 1,
#   'déjà': 1,
#   'laissé': 1,
#   'conquis': 1,
#   'récompensé': 1,
#   'lu': 1,
#   'seulement': 1,
#   'raconté': 2,
#   'eu': 6,
#   'même': 3,
#   'excité': 2,
#   'ravi': 1,
#   'reconnu': 1,
#   'dû': 1,
#   'autour': 1,
#   'repoussées': 1,
#   'produit,': 1,
#   'tenu': 1,
#   'plus': 1,
#   'fait,': 2,
#   'rendu.': 1,
#   'chassé': 1,
#   'quelques': 1,
#   'fait': 5,
#   'le': 2,
#   'pourtant': 1,
#   'mené': 1,
#   'eu,': 1,
#   'consacré': 1,
#   'offensé.': 1,
#   'perdu': 1,
#   'quatre': 1,
#   'toujours': 1,
#   'pas': 5,
#   'subi': 1,
#   'des': 2,
#   'un': 6,
#   'apprécié': 1,
#   'rien': 1,
#   'pris': 1,
#   'en': 2,
#   'fini': 1,
#   'dit': 7,
#   'pu': 2,
#   'surtout': 1,
#   'jamais': 2,
#   'si': 1,
#   'énormément': 1,
#   'guère': 1,
#   'construites.»': 1,
#   "l'air": 1,
#   'encore': 3,
#   'bien': 1,
#   'sombré': 1,
#   'pu.': 1,
#   'entendues': 2,
#   'vu': 1,
#   'que': 2,
#   'remplacées.': 1,
#   'inscrits': 1,
#   "l'intention": 1,
#   'à': 1,
#   'relu': 1,
#   'appris': 1,
#   'assez': 1,
#   'précédé': 1,
#   'là': 3,
#   'les': 1,
#   'anéanti.': 1,
#   'au': 2,
#   'écrit': 1,
#   'exprimées': 1,
#   'dans': 1,
#   'vice': 1,
#   'lieu': 1,
#   'entre': 1,
#   'voulu': 1,
#   'donné': 1,
#   "qu'une": 1,
#   'pour': 1,
#   'prévu': 1,
#   'peu': 1,
#   'épousé': 1,
#   'quand': 1,
#   'chez': 1,
#   'absorbée,': 1,
#   'parlé': 1,
#   'diminué': 1,
#   'obtenu': 1,
#   'notre': 1,
#   'permis': 1,
#   'péri': 1,
#   '_des': 1,
#   'failli': 1,
#   'réussi': 1},
#  'vraiment': {'de': 2,
#   'plus': 1,
#   'le': 1,
#   'considéré': 1,
#   'rares,': 1,
#   'nouveau.': 1,
#   'un': 1,
#   'que': 2,
#   'supérieurs.': 1,
#   'lui-même': 1,
#   'intelligible': 1,
#   'divin,': 1,
#   'trop': 1},
#  "l'importance,": {'nous': 1, 'sont': 1},
#  "s'intéressait": {'beaucoup': 1},
#  'étrangère.': {'Je': 1},
#  'sais': {'bien': 1,
#   'que,': 1,
#   'combien': 1,
#   'que': 3,
#   'si': 1,
#   'pas': 4,
#   'moi': 1,
#   'plus.': 1,
#   'ce': 1,
#   'même': 1},
#  'boutonné,': {'mais': 1},
#  'moi,': {'il': 1,
#   'les': 1,
#   'alors,': 1,
#   'je': 5,
#   'en': 3,
#   'devait': 1,
#   'ajouta-t-il': 1,
#   'mais': 5,
#   'au': 2,
#   'et': 1,
#   "c'était": 1,
#   'cette': 1,
#   'Cottard,': 1,
#   'comme': 1,
#   "m'avaient": 1,
#   'que': 1,
#   'la': 1,
#   'déjà': 1,
#   "n'est-ce": 1,
#   'ce': 2,
#   'gardait': 1,
#   'par': 1,
#   'aller': 1,
#   'me': 1,
#   "j'entendais": 1,
#   'peut-être': 1,
#   'à': 1,
#   'vous': 2,
#   'de': 2,
#   'rien': 1,
#   'cause': 1,
#   'sur': 1,
#   'disproportion': 1,
#   'chaque': 1,
#   'fidèle': 1},
#  "s'ouvre": {'si': 1},
#  "l'Ambassadeur": {"n'avait-il": 1,
#   'pour': 1,
#   'avait': 1,
#   'comme': 1,
#   'après': 1,
#   'parti,': 1,
#   'et': 1},
#  "n'avait-il": {'pas': 1},
#  "d'intelligence": {'vers': 1, 'à': 1, 'un': 1, 'répandue': 1},
#  'vers': {'lequel': 2,
#   'la': 4,
#   "l'implacable": 1,
#   'que': 2,
#   'mon': 2,
#   'le': 2,
#   'ma': 1,
#   'Vaugoubert': 1,
#   "qu'elle": 1,
#   'deux': 1,
#   'ses': 2,
#   'laquelle': 1,
#   'moi.': 1,
#   'ce': 1,
#   'moi': 1,
#   'une': 1,
#   'lui,': 1,
#   'cette': 1,
#   'cet': 1,
#   'elle': 1,
#   'de': 1,
#   'moi:': 1,
#   'Mme': 1},
#  'sentait': {'le': 1,
#   'que': 1,
#   "qu'elles": 1,
#   'si': 1,
#   'bien': 1,
#   'en': 1,
#   'plus': 1},
#  'dois': {'dire': 2, 'ramener': 1, 'dire,': 1},
#  'conversation': {'de': 2,
#   'si': 1,
#   'et': 5,
#   'où': 3,
#   'se': 1,
#   'sur': 2,
#   'on': 1,
#   'après': 1,
#   'par': 1,
#   'la': 1,
#   'en': 1,
#   'plus': 1,
#   'avec': 1,
#   'à': 1,
#   'ponctuée': 1,
#   "quelqu'une": 1,
#   'Mme': 1,
#   'chez': 1},
#  'répertoire': {'si': 1},
#  'complet': {'des': 1},
#  'formes': {'surannées': 1, 'plus': 1, 'que': 1, 'de': 1},
#  'surannées': {'du': 1},
#  'langage': {'particulières': 1,
#   'des': 2,
#   'natal': 1,
#   'plus': 1,
#   'connu': 1,
#   'avait': 1,
#   'avaient': 1,
#   'de': 2,
#   'éloquent': 1,
#   'assez': 1,
#   'noble': 1},
#  'particulières': {'à': 1, 'aux': 1, 'sous': 1, 'qui': 1},
#  'classe,': {'et': 1},
#  'temps--un': {'temps': 1},
#  'temps': {'qui,': 1,
#   'à': 7,
#   'que': 8,
#   'attaché': 1,
#   "d'une": 1,
#   'le': 2,
#   'où': 3,
#   'se': 1,
#   'comme': 2,
#   'de': 9,
#   'il': 1,
#   'ses': 1,
#   "d'en": 1,
#   'mon': 1,
#   "l'illusion": 1,
#   'auparavant,': 1,
#   'lointain': 1,
#   'en': 2,
#   'demander': 1,
#   'avant': 1,
#   'successifs': 1,
#   'du': 2,
#   'mêle': 1,
#   'quotidien': 1,
#   'et': 1,
#   'encore': 1,
#   'précieux:': 1,
#   '(et': 1,
#   'là': 1,
#   'déjà': 1,
#   "qu'il": 1,
#   'pour': 1,
#   "d'aller": 1,
#   'ne': 1,
#   'avait': 1},
#  'carrière': {'et': 1, 'des': 1, 'de': 1},
#  'classe-là,': {'pourrait': 1},
#  'pourrait': {'bien': 2,
#   "t'y": 1,
#   'pas': 2,
#   'dire': 1,
#   'lui': 1,
#   '_se': 1,
#   'jamais': 1,
#   'nommer': 1,
#   'voir': 1,
#   "l'endommager.": 1,
#   'en': 1,
#   'presque': 1,
#   'raisonner': 1,
#   'être': 1,
#   'durer.': 1,
#   'au': 1,
#   'accrocher': 1,
#   'venir': 1},
#  ...}

# %%
def chaine_markov_bigramme(corpus):
	transitions = compter_transitions_bigrammes(corpus)
	return probabilify(transitions)

# %%
markov_chain = chaine_markov_bigramme(corpus)

# %%
print(markov_chain["le"])
# Out:
# {'regret': 0.001081081081081081, 'Professeur': 0.001081081081081081, 'marquis': 0.002162162162162162, 'désir,': 0.002162162162162162, 'rang': 0.001081081081081081, 'plaisir': 0.004324324324324324, 'snobisme': 0.001081081081081081, 'plus': 0.03567567567567568, 'reverra,': 0.001081081081081081, 'changement': 0.002162162162162162, 'père': 0.0075675675675675675, 'fard': 0.002162162162162162, 'phénomène': 0.001081081081081081, 'don': 0.004324324324324324, 'seul': 0.006486486486486486, 'prendre.': 0.001081081081081081, 'monde,': 0.008648648648648649, 'passé': 0.003243243243243243, 'rendre': 0.002162162162162162, '_Journal': 0.001081081081081081, 'peut': 0.001081081081081081, 'mépris': 0.002162162162162162, 'moins': 0.005405405405405406, 'retour': 0.001081081081081081, 'premier.': 0.001081081081081081, 'monde': 0.018378378378378378, 'gala': 0.001081081081081081, 'souverain': 0.001081081081081081, 'genre': 0.006486486486486486, 'domaine,': 0.001081081081081081, 'conduisant': 0.001081081081081081, 'service': 0.002162162162162162, 'louer': 0.001081081081081081, 'même': 0.02918918918918919, 'régime': 0.002162162162162162, 'nom': 0.014054054054054054, 'ramènerai': 0.001081081081081081, 'directeur': 0.002162162162162162, 'jour': 0.014054054054054054, 'prestige': 0.002162162162162162, 'départ': 0.001081081081081081, 'titre': 0.004324324324324324, 'particulier': 0.001081081081081081, 'programme': 0.001081081081081081, 'temps': 0.011891891891891892, 'sous-entendu': 0.001081081081081081, 'rideau': 0.003243243243243243, 'théâtre,': 0.002162162162162162, 'reste': 0.002162162162162162, 'monument': 0.001081081081081081, 'four': 0.001081081081081081, 'vocabulaire': 0.002162162162162162, 'mot': 0.006486486486486486, 'petit': 0.0075675675675675675, 'théâtre': 0.001081081081081081, 'sort,': 0.001081081081081081, 'pouvoir': 0.005405405405405406, 'milieu': 0.003243243243243243, 'symbole': 0.002162162162162162, 'centre': 0.002162162162162162, 'poussin': 0.001081081081081081, 'public': 0.004324324324324324, 'compte': 0.002162162162162162, 'récompensât': 0.001081081081081081, 'génie': 0.002162162162162162, 'fond,': 0.001081081081081081, 'soin': 0.002162162162162162, 'rôle': 0.003243243243243243, 'son': 0.004324324324324324, 'talent': 0.001081081081081081, 'décor': 0.001081081081081081, 'tableau': 0.001081081081081081, 'verre': 0.002162162162162162, 'moment': 0.008648648648648649, 'surprend': 0.001081081081081081, 'peuple': 0.001081081081081081, 'coup': 0.001081081081081081, 'vent': 0.004324324324324324, 'vin': 0.001081081081081081, 'besoin': 0.004324324324324324, 'prolonger,': 0.001081081081081081, 'dîner': 0.003243243243243243, 'meilleur': 0.002162162162162162, 'désir.': 0.001081081081081081, 'conseil': 0.002162162162162162, 'caractère': 0.005405405405405406, 'marteau': 0.001081081081081081, 'fils': 0.004324324324324324, 'quai': 0.001081081081081081, 'fusil': 0.001081081081081081, 'succès': 0.002162162162162162, 'voir': 0.003243243243243243, 'lendemain': 0.0075675675675675675, '4%': 0.001081081081081081, 'revenu': 0.001081081081081081, 'capital.»': 0.001081081081081081, 'reste,': 0.002162162162162162, 'sourire': 0.002162162162162162, 'dernier': 0.003243243243243243, 'rendit.': 0.001081081081081081, 'faisait': 0.003243243243243243, 'ton': 0.005405405405405406, 'piano,': 0.001081081081081081, 'diplomate': 0.001081081081081081, 'prier': 0.001081081081081081, 'provoquer': 0.001081081081081081, 'goût': 0.008648648648648649, 'choix': 0.002162162162162162, 'jeu': 0.001081081081081081, 'bœuf': 0.002162162162162162, 'parfum': 0.004324324324324324, 'trouver': 0.001081081081081081, 'critérium': 0.001081081081081081, 'mets': 0.001081081081081081, 'roi': 0.0075675675675675675, 'veux': 0.002162162162162162, 'nôtre': 0.002162162162162162, 'rapprochement': 0.001081081081081081, 'Ministre': 0.001081081081081081, 'connais': 0.002162162162162162, 'connaîtrait?': 0.001081081081081081, 'cœur': 0.004324324324324324, 'sien.': 0.001081081081081081, 'candidat': 0.0010810810810810 ...

# %%
ponctuation = [".", "!", "?", "…", ":", ";", ",", "(", ")", "[", "]", "{", "}", "«", "»", "“", "”", "‘", "’", "—", "–", "-", " ", "\n", "\t", "\r "]
NB_MOTS_MAXI = 100

# %%
def generate_bi(markov_chain, start_token):
	phrase = []
	maximum = NB_MOTS_MAXI
	token = start_token
	while len(phrase) < maximum:
		if token in markov_chain:
			next_tokens = markov_chain[token]
			token = max(next_tokens, key=next_tokens.get)
			phrase.append(token)
			if token in ponctuation:
				break
		else:
			break
	return ' '.join(phrase)

# %%
print(generate_bi(markov_chain, "Si"))
# Out:
# Swann et de la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la Berma dans la

# %%
import random

def generate_bi(markov_chain, start_token, n_best=1):
	phrase = []
	maximum = NB_MOTS_MAXI
	token = start_token
	while len(phrase) < maximum:
		if token in markov_chain:
			next_tokens = list(markov_chain[token].items())
			next_tokens.sort(key=lambda x: x[1], reverse=True)
			top_tokens = next_tokens[:n_best] if len(next_tokens) > n_best else next_tokens
			token, _ = random.choice(top_tokens)
			phrase.append(token)
			if token in ponctuation:
				break
		else:
			break
	return ' '.join(phrase)

# %%
print(generate_bi(markov_chain, "Si", 2))
# Out:
# j'avais été la vie de la vie et de la Berma les plus que le plus que je ne pas de sa mère qui me semblait que je ne pas de la Berma dans le plus de la Berma les autres et de la Berma dans la Berma dans le plus que je ne me dit à la Berma les autres par le plus de la vie et qui me dit à la vie de la Berma les plus de la Berma dans le même pas à la vie de la Berma les plus que le même que je me

# %%
print(generate_bi(markov_chain, "Si", 10))
# Out:
# donc en effet, je suis laissé aller pêcher ce qu'on avait dit ma mémoire n'est que ce qu'elle pût avoir connu jadis, j'avoue que nous ne se sentait que dans son air découragé qui nous ne peut surprendre puisqu'il était pas de mon mari que vous vous a pas de lui avait à ce fut changé, et que j'avais pu aller au lieu du mal sans en effet dès qu'ils se faisait maintenant bénéficier Odette qui avait pour une sorte de Norpois est un moment voulu, au lieu précisément le lui et le plus de la femme à un jour
